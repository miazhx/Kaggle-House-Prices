# %%
# MLflow Training
def train_elasticnet(N_alpha, N_rho):
    import os
    import warnings
    import sys

    import pandas as pd
    import numpy as np
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import ElasticNet

    import mlflow
    import mlflow.sklearn
    
    import logging
    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)
    
    from data_processing import data_process

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        r2_test = r2_score(actual, pred)
        return rmse, r2_test


    warnings.filterwarnings("ignore")
    np.random.seed(40)

#     # Read the file
#     try:
#         df_raw = pd.read_csv('train.csv',index_col=0)
#     except Exception as e:
#         logger.exception(
#             "Unable to download training & test CSV, check your internet connection. Error: %s", e)
        
    # Data processing.
    df_processed = data_process()
    
    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(df_processed)

    # The predicted column is "SalePrice" .
    train_x = train.drop(["SalePrice"], axis=1)
    test_x = test.drop(["SalePrice"], axis=1)
    train_y = train[["SalePrice"]]
    test_y = test[["SalePrice"]]

    # Set default values if no N_alpha is provided
    if int(N_alpha) is None:
        N_alpha = 50
    else:
        N_alpha = int(N_alpha)

    # Set default values if no N_rho is provided
    if int(N_rho) is None:
        N_rho = 11
    else:
        N_rho = int(N_rho)
    
    alphaRange = np.logspace(-3, -1, N_alpha)
    rhoRange   = np.linspace(0,0.4, N_rho) # we avoid very small rho by starting at 0.1
    scores     = np.zeros((N_rho, N_alpha))
      
    
    # Execute ElasticNet
    for alphaIdx, alpha in enumerate(alphaRange):
        for rhoIdx, rho in enumerate(rhoRange):
            with mlflow.start_run():
                lr = ElasticNet(alpha=alpha, l1_ratio=rho, normalize=False)
                lr.fit(train_x, train_y)
                r2_train = lr.score(train_x, train_y)
        
        # Training Model Performances Evaluate Metrics
#         predicted_qualities = lr.predict(test_x)
#         (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)        

        # Evaluate Metrics
                predicted_qualities = lr.predict(test_x)
                (rmse, r2_test) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
                print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, rho))
                print("  RMSE: %s" % rmse)
                print("  Train R2: %s" % r2_train)
                print("  Test R2: %s" % r2_test)

        # Log parameter, metrics, and model to MLflow
                mlflow.log_param("model", 'elasticnet')
                mlflow.log_param("alpha", alpha)
                mlflow.log_param("l1_ratio", rho)
                mlflow.log_metric("rmse", rmse)
                mlflow.log_metric("r2_test", r2_test)
                mlflow.log_metric("r2_train", r2_train)
                #mlflow.log_metric("mae", mae)

                mlflow.sklearn.log_model(lr, "model")

# %%
train_elasticnet(30,11)
# Out:
# Elasticnet model (alpha=0.001000, l1_ratio=0.000000):
#   RMSE: 0.10603442082756895
#   Train R2: 0.948723686380187
#   Test R2: 0.9340260316005999
# Elasticnet model (alpha=0.001000, l1_ratio=0.040000):
#   RMSE: 0.10468283092919625
#   Train R2: 0.9476117001751545
#   Test R2: 0.9356972141870353
# Elasticnet model (alpha=0.001000, l1_ratio=0.080000):
#   RMSE: 0.1039805609206908
#   Train R2: 0.9463462791923181
#   Test R2: 0.9365570771743933
# Elasticnet model (alpha=0.001000, l1_ratio=0.120000):
#   RMSE: 0.10378596015196268
#   Train R2: 0.9452315187718907
#   Test R2: 0.9367943232243552
# Elasticnet model (alpha=0.001000, l1_ratio=0.160000):
#   RMSE: 0.10380739312853685
#   Train R2: 0.9443239070517755
#   Test R2: 0.9367682151521904
# Elasticnet model (alpha=0.001000, l1_ratio=0.200000):
#   RMSE: 0.10405682513230399
#   Train R2: 0.9435189441849268
#   Test R2: 0.9364639790258086
# Elasticnet model (alpha=0.001000, l1_ratio=0.240000):
#   RMSE: 0.10444840708655084
#   Train R2: 0.9427317979065419
#   Test R2: 0.9359848874901124
# Elasticnet model (alpha=0.001000, l1_ratio=0.280000):
#   RMSE: 0.10448421236496366
#   Train R2: 0.9421678267002186
#   Test R2: 0.9359409907595386
# Elasticnet model (alpha=0.001000, l1_ratio=0.320000):
#   RMSE: 0.10457559875472387
#   Train R2: 0.941512953137862
#   Test R2: 0.9358288842204375
# Elasticnet model (alpha=0.001000, l1_ratio=0.360000):
#   RMSE: 0.10472446698496124
#   Train R2: 0.940820278785881
#   Test R2: 0.9356460530408687
# Elasticnet model (alpha=0.001000, l1_ratio=0.400000):
#   RMSE: 0.10483082189951114
#   Train R2: 0.9402001161375423
#   Test R2: 0.9355152749297766
# Elasticnet model (alpha=0.001172, l1_ratio=0.000000):
#   RMSE: 0.10579499472325166
#   Train R2: 0.9483967771259698
#   Test R2: 0.9343236341437842
# Elasticnet model (alpha=0.001172, l1_ratio=0.040000):
#   RMSE: 0.1044356256249108
#   Train R2: 0.9470994066993443
#   Test R2: 0.9360005537250573
# Elasticnet model (alpha=0.001172, l1_ratio=0.080000):
#   RMSE: 0.10396601118567887
#   Train R2: 0.9457103193596831
#   Test R2: 0.9365748307453563
# Elasticnet model (alpha=0.001172, l1_ratio=0.120000):
#   RMSE: 0.10384189240235597
#   Train R2: 0.9445542415854294
#   Test R2: 0.9367261793571542
# Elasticnet model (alpha=0.001172, l1_ratio=0.160000):
#   RMSE: 0.10403696991547427
#   Train R2: 0.9436118530949545
#   Test R2: 0.9364882234925231
# Elasticnet model (alpha=0.001172, l1_ratio=0.200000):
#   RMSE: 0.10444843883963859
#   Train R2: 0.9427250593013958
#   Test R2: 0.9359848485679718
# Elasticnet model (alpha=0.001172, l1_ratio=0.240000):
#   RMSE: 0.10449562424582351
#   Train R2: 0.9420654950164561
#   Test R2: 0.9359269968041446
# Elasticnet model (alpha=0.001172, l1_ratio=0.280000):
#   RMSE: 0.10462379115121648
#   Train R2: 0.941299881778044
#   Test R2: 0.9357697256313171
# Elasticnet model (alpha=0.001172, l1_ratio=0.320000):
#   RMSE: 0.10477246224474421
#   Train R2: 0.940514503719938
#   Test R2: 0.9355870526512964
# Elasticnet model (alpha=0.001172, l1_ratio=0.360000):
#   RMSE: 0.1049276702033864
#   Train R2: 0.9398566662138176
#   Test R2: 0.935396071035791
# Elasticnet model (alpha=0.001172, l1_ratio=0.400000):
#   RMSE: 0.1050752047605434
#   Train R2: 0.9392870466556297
#   Test R2: 0.9352142693655887
# Elasticnet model (alpha=0.001374, l1_ratio=0.000000):
#   RMSE: 0.1055810911916799
#   Train R2: 0.9480524716626635
#   Test R2: 0.9345889435683206
# Elasticnet model (alpha=0.001374, l1_ratio=0.040000):
#   RMSE: 0.10427681455104619
#   Train R2: 0.9465561717930525
#   Test R2: 0.9361950485226181
# Elasticnet model (alpha=0.001374, l1_ratio=0.080000):
#   RMSE: 0.10397019815052745
#   Train R2: 0.9450816464037438
#   Test R2: 0.936569722069963
# Elasticnet model (alpha=0.001374, l1_ratio=0.120000):
#   RMSE: 0.10399185683880059
#   Train R2: 0.9438858888969018
#   Test R2: 0.9365432921941831
# Elasticnet model (alpha=0.001374, l1_ratio=0.160000):
#   RMSE: 0.10442225805105017
#   Train R2: 0.9428419657729981
#   Test R2: 0.9360169363065309
# Elasticnet model (alpha=0.001374, l1_ratio=0.200000):
#   RMSE: 0.10450002541333389
#   Train R2: 0.9420695390604408
#   Test R2: 0.9359215994114676
# Elasticnet model (alpha=0.001374, l1_ratio=0.240000):
#   RMSE: 0.10465571930757063
#   Train R2: 0.9411898999957157
#   Test R2: 0.935730517203949
# Elasticnet model (alpha=0.001374, l1_ratio=0.280000):
#   RMSE: 0.10482471899255628
#   Train R2: 0.9402965583498848
#   Test R2: 0.9355227828900226
# Elasticnet model (alpha=0.001374, l1_ratio=0.320000):
#   RMSE: 0.10500239628734705
#   Train R2: 0.9395841244834311
#   Test R2: 0.9353040206235366
# Elasticnet model (alpha=0.001374, l1_ratio=0.360000):
#   RMSE: 0.10518664943301229
#   Train R2: 0.9389257043883886
#   Test R2: 0.9350767706399415
# Elasticnet model (alpha=0.001374, l1_ratio=0.400000):
#   RMSE: 0.10542063705083592
#   Train R2: 0.9382880576044836
#   Test R2: 0.9347876060301199
# Elasticnet model (alpha=0.001610, l1_ratio=0.000000):
#   RMSE: 0.10539252620368249
#   Train R2: 0.9476917520471639
#   Test R2: 0.9348223797002239
# Elasticnet model (alpha=0.001610, l1_ratio=0.040000):
#   RMSE: 0.1041888511044246
#   Train R2: 0.9459909272419599
#   Test R2: 0.9363026493586061
# Elasticnet model (alpha=0.001610, l1_ratio=0.080000):
#   RMSE: 0.10401432877982068
#   Train R2: 0.9444206375669854
#   Test R2: 0.9365158640952433
# Elasticnet model (alpha=0.001610, l1_ratio=0.120000):
#   RMSE: 0.10427977579348617
#   Train R2: 0.9431619772771535
#   Test R2: 0.9361914246180372
# Elasticnet model (alpha=0.001610, l1_ratio=0.160000):
#   RMSE: 0.10449695266416388
#   Train R2: 0.9422071785731223
#   Test R2: 0.9359253677159562
# Elasticnet model (alpha=0.001610, l1_ratio=0.200000):
#   RMSE: 0.10466139948674427
#   Train R2: 0.941218770382911
#   Test R2: 0.9357235405745407
# Elasticnet model (alpha=0.001610, l1_ratio=0.240000):
#   RMSE: 0.10485706124979738
#   Train R2: 0.9401924676869567
#   Test R2: 0.9354829895957764
# Elasticnet model (alpha=0.001610, l1_ratio=0.280000):
#   RMSE: 0.10506765205250038
#   Train R2: 0.9393807650228185
#   Test R2: 0.9352235825070565
# Elasticnet model (alpha=0.001610, l1_ratio=0.320000):
#   RMSE: 0.10528093671199001
#   Train R2: 0.9386321779405075
#   Test R2: 0.9349603266189626
# Elasticnet model (alpha=0.001610, l1_ratio=0.360000):
#   RMSE: 0.10566965356196242
#   Train R2: 0.937829068033353
#   Test R2: 0.9344791627784533
# Elasticnet model (alpha=0.001610, l1_ratio=0.400000):
#   RMSE: 0.10596928577660183
#   Train R2: 0.9372171333037467
#   Test R2: 0.9341070599668341
# Elasticnet model (alpha=0.001887, l1_ratio=0.000000):
#   RMSE: 0.10522897867111243
#   Train R2: 0.9473155599711965
#   Test R2: 0.9350245072813422
# Elasticnet model (alpha=0.001887, l1_ratio=0.040000):
#   RMSE: 0.10415680379985975
#   Train R2: 0.9453912629374475
#   Test R2: 0.9363418284920673
# Elasticnet model (alpha=0.001887, l1_ratio=0.080000):
#   RMSE: 0.10411898764843165
#   Train R2: 0.9437535307814494
#   Test R2: 0.9363880447728241
# Elasticnet model (alpha=0.001887, l1_ratio=0.120000):
#   RMSE: 0.10446351734716852
#   Train R2: 0.9425105280765813
#   Test R2: 0.9359663643737204
# Elasticnet model (alpha=0.001887, l1_ratio=0.160000):
#   RMSE: 0.10463275912092652
#   Train R2: 0.9414191530315987
#   Test R2: 0.9357587139897846
# Elasticnet model (alpha=0.001887, l1_ratio=0.200000):
#   RMSE: 0.10486717852135931
#   Train R2: 0.9402353277203152
#   Test R2: 0.9354705389778228
# Elasticnet model (alpha=0.001887, l1_ratio=0.240000):
#   RMSE: 0.10510984077597062
#   Train R2: 0.9392769201755521
#   Test R2: 0.9351715515920999
# Elasticnet model (alpha=0.001887, l1_ratio=0.280000):
#   RMSE: 0.10548325888016623
#   Train R2: 0.9383353972533155
#   Test R2: 0.9347101082569605
# Elasticnet model (alpha=0.001887, l1_ratio=0.320000):
#   RMSE: 0.10583614327828002
#   Train R2: 0.9374870186434484
#   Test R2: 0.934272535070097
# Elasticnet model (alpha=0.001887, l1_ratio=0.360000):
#   RMSE: 0.10619486012509492
#   Train R2: 0.9368380356343315
#   Test R2: 0.9338262318575234
# Elasticnet model (alpha=0.001887, l1_ratio=0.400000):
#   RMSE: 0.10657538619285505
#   Train R2: 0.936201454499666
#   Test R2: 0.9333511437266089
# Elasticnet model (alpha=0.002212, l1_ratio=0.000000):
#   RMSE: 0.10509008856799752
#   Train R2: 0.9469247210223832
#   Test R2: 0.9351959143857266
# Elasticnet model (alpha=0.002212, l1_ratio=0.040000):
#   RMSE: 0.10417728607262652
#   Train R2: 0.9448137943835134
#   Test R2: 0.9363167894703903
# Elasticnet model (alpha=0.002212, l1_ratio=0.080000):
#   RMSE: 0.10436940293704339
#   Train R2: 0.9430589140644754
#   Test R2: 0.9360816921603691
# Elasticnet model (alpha=0.002212, l1_ratio=0.120000):
#   RMSE: 0.10457013184968839
#   Train R2: 0.9418287656354748
#   Test R2: 0.9358355933998315
# Elasticnet model (alpha=0.002212, l1_ratio=0.160000):
#   RMSE: 0.10484548437733472
#   Train R2: 0.9404843049322209
#   Test R2: 0.9354972349686816
# Elasticnet model (alpha=0.002212, l1_ratio=0.200000):
#   RMSE: 0.10512211741972562
#   Train R2: 0.9393071080122892
#   Test R2: 0.9351564070111765
# Elasticnet model (alpha=0.002212, l1_ratio=0.240000):
#   RMSE: 0.10560787665595509
#   Train R2: 0.9381793925736668
#   Test R2: 0.9345557503565214
# Elasticnet model (alpha=0.002212, l1_ratio=0.280000):
#   RMSE: 0.10597801510575561
#   Train R2: 0.937264789996518
#   Test R2: 0.9340962035219759
# Elasticnet model (alpha=0.002212, l1_ratio=0.320000):
#   RMSE: 0.10640843021659824
#   Train R2: 0.9365000646467404
#   Test R2: 0.9335597980775444
# Elasticnet model (alpha=0.002212, l1_ratio=0.360000):
#   RMSE: 0.10686638891369439
#   Train R2: 0.9357761864500039
#   Test R2: 0.9329866791329136
# Elasticnet model (alpha=0.002212, l1_ratio=0.400000):
#   RMSE: 0.10734939725331596
#   Train R2: 0.9350418539561987
#   Test R2: 0.9323795445485524
# Elasticnet model (alpha=0.002593, l1_ratio=0.000000):
#   RMSE: 0.10497555209224047
#   Train R2: 0.9465198656080448
#   Test R2: 0.9353370958590835
# Elasticnet model (alpha=0.002593, l1_ratio=0.040000):
#   RMSE: 0.10422883343633368
#   Train R2: 0.944219154890635
#   Test R2: 0.9362537524325417
# Elasticnet model (alpha=0.002593, l1_ratio=0.080000):
#   RMSE: 0.10447623346375977
#   Train R2: 0.9424615252429378
#   Test R2: 0.9359507740747134
# Elasticnet model (alpha=0.002593, l1_ratio=0.120000):
#   RMSE: 0.10474749909265217
#   Train R2: 0.9410059968892776
#   Test R2: 0.9356177431325795
# Elasticnet model (alpha=0.002593, l1_ratio=0.160000):
#   RMSE: 0.10507432365724197
#   Train R2: 0.9395162660045007
#   Test R2: 0.9352153558765681
# Elasticnet model (alpha=0.002593, l1_ratio=0.200000):
#   RMSE: 0.10564477927953049
#   Train R2: 0.9382018326439612
#   Test R2: 0.9345100059189856
# Elasticnet model (alpha=0.002593, l1_ratio=0.240000):
#   RMSE: 0.10607411520998347
#   Train R2: 0.9371396583171032
#   Test R2: 0.9339766271508252
# Elasticnet model (alpha=0.002593, l1_ratio=0.280000):
#   RMSE: 0.10658320839187124
#   Train R2: 0.9362501367774945
#   Test R2: 0.9333413598587058
# Elasticnet model (alpha=0.002593, l1_ratio=0.320000):
#   RMSE: 0.10712689248299356
#   Train R2: 0.9354035436409777
#   Test R2: 0.9326595699867032
# Elasticnet model (alpha=0.002593, l1_ratio=0.360000):
#   RMSE: 0.10771124446589771
#   Train R2: 0.9345298131495245
#   Test R2: 0.931922913918585
# Elasticnet model (alpha=0.002593, l1_ratio=0.400000):
#   RMSE: 0.1083496703816842
#   Train R2: 0.9335955797622689
#   Test R2: 0.9311135094648189
# Elasticnet model (alpha=0.003039, l1_ratio=0.000000):
#   RMSE: 0.10488520954820392
#   Train R2: 0.9461013511070023
#   Test R2: 0.935448346476982
# Elasticnet model (alpha=0.003039, l1_ratio=0.040000):
#   RMSE: 0.10432243832569506
#   Train R2: 0.9435821264654015
#   Test R2: 0.9361392037106399
# Elasticnet model (alpha=0.003039, l1_ratio=0.080000):
#   RMSE: 0.1046099297723832
#   Train R2: 0.9417935292145274
#   Test R2: 0.9357867439629509
# Elasticnet model (alpha=0.003039, l1_ratio=0.120000):
#   RMSE: 0.1049774839900747
#   Train R2: 0.9400551766371209
#   Test R2: 0.935334715813988
# Elasticnet model (alpha=0.003039, l1_ratio=0.160000):
#   RMSE: 0.10559133760325701
#   Train R2: 0.9384487969403723
#   Test R2: 0.9345762469553109
# Elasticnet model (alpha=0.003039, l1_ratio=0.200000):
#   RMSE: 0.1060991552827779
#   Train R2: 0.9371474407918109
#   Test R2: 0.9339454522465342
# Elasticnet model (alpha=0.003039, l1_ratio=0.240000):
#   RMSE: 0.10669418187882684
#   Train R2: 0.9361085862476293
#   Test R2: 0.9332024788310652
# Elasticnet model (alpha=0.003039, l1_ratio=0.280000):
#   RMSE: 0.10733572026616787
#   Train R2: 0.9351140379045966
#   Test R2: 0.9323967739920025
# Elasticnet model (alpha=0.003039, l1_ratio=0.320000):
#   RMSE: 0.10803671158072053
#   Train R2: 0.9340731242460254
#   Test R2: 0.9315108802785131
# Elasticnet model (alpha=0.003039, l1_ratio=0.360000):
#   RMSE: 0.1087758354141061
#   Train R2: 0.9329721623323486
#   Test R2: 0.9305705498521486
# Elasticnet model (alpha=0.003039, l1_ratio=0.400000):
#   RMSE: 0.1094709564099985
#   Train R2: 0.9318754396881971
#   Test R2: 0.9296803507625023
# Elasticnet model (alpha=0.003562, l1_ratio=0.000000):
#   RMSE: 0.10481911950383488
#   Train R2: 0.9456691894598358
#   Test R2: 0.9355296711471155
# Elasticnet model (alpha=0.003562, l1_ratio=0.040000):
#   RMSE: 0.1044260787711806
#   Train R2: 0.9429457925832523
#   Test R2: 0.9360122540509211
# Elasticnet model (alpha=0.003562, l1_ratio=0.080000):
#   RMSE: 0.10477933683659507
#   Train R2: 0.9410223307079518
#   Test R2: 0.9355785995283877
# Elasticnet model (alpha=0.003562, l1_ratio=0.120000):
#   RMSE: 0.10540484655379646
#   Train R2: 0.9390063374644804
#   Test R2: 0.9348071403266842
# Elasticnet model (alpha=0.003562, l1_ratio=0.160000):
#   RMSE: 0.106048803120037
#   Train R2: 0.937407286227558
#   Test R2: 0.934008133237938
# Elasticnet model (alpha=0.003562, l1_ratio=0.200000):
#   RMSE: 0.10671351163898486
#   Train R2: 0.9361165904725138
#   Test R2: 0.9331782732558033
# Elasticnet model (alpha=0.003562, l1_ratio=0.240000):
#   RMSE: 0.10746469638157649
#   Train R2: 0.9349494994921123
#   Test R2: 0.9322342104015089
# Elasticnet model (alpha=0.003562, l1_ratio=0.280000):
#   RMSE: 0.10829010161884564
#   Train R2: 0.9337222012482167
#   Test R2: 0.9311892338300385
# Elasticnet model (alpha=0.003562, l1_ratio=0.320000):
#   RMSE: 0.10912087409525607
#   Train R2: 0.9324424429946772
#   Test R2: 0.9301293886331539
# Elasticnet model (alpha=0.003562, l1_ratio=0.360000):
#   RMSE: 0.10983252833406065
#   Train R2: 0.9312472445485585
#   Test R2: 0.9292150657066386
# Elasticnet model (alpha=0.003562, l1_ratio=0.400000):
#   RMSE: 0.11045797844737593
#   Train R2: 0.930130259579776
#   Test R2: 0.9284065893410761
# Elasticnet model (alpha=0.004175, l1_ratio=0.000000):
#   RMSE: 0.10477761249268099
#   Train R2: 0.9452229833956798
#   Test R2: 0.9355807198650712
# Elasticnet model (alpha=0.004175, l1_ratio=0.040000):
#   RMSE: 0.10446151894388625
#   Train R2: 0.9423506306034227
#   Test R2: 0.9359688142970404
# Elasticnet model (alpha=0.004175, l1_ratio=0.080000):
#   RMSE: 0.10508394787835428
#   Train R2: 0.9400885980977203
#   Test R2: 0.9352034875100127
# Elasticnet model (alpha=0.004175, l1_ratio=0.120000):
#   RMSE: 0.1059087729659392
#   Train R2: 0.9379553595772491
#   Test R2: 0.9341822936253404
# Elasticnet model (alpha=0.004175, l1_ratio=0.160000):
#   RMSE: 0.10662178430107176
#   Train R2: 0.9363485631412914
#   Test R2: 0.9332930992925638
# Elasticnet model (alpha=0.004175, l1_ratio=0.200000):
#   RMSE: 0.1074812129014597
#   Train R2: 0.9349612150882344
#   Test R2: 0.932213378610985
# Elasticnet model (alpha=0.004175, l1_ratio=0.240000):
#   RMSE: 0.10843056716048903
#   Train R2: 0.933536817513977
#   Test R2: 0.9310106060497942
# Elasticnet model (alpha=0.004175, l1_ratio=0.280000):
#   RMSE: 0.10938452549373612
#   Train R2: 0.9320424917248672
#   Test R2: 0.9297913462741152
# Elasticnet model (alpha=0.004175, l1_ratio=0.320000):
#   RMSE: 0.11015334708358343
#   Train R2: 0.930696124855738
#   Test R2: 0.9288009388368159
# Elasticnet model (alpha=0.004175, l1_ratio=0.360000):
#   RMSE: 0.11090693534508217
#   Train R2: 0.9293781921393076
#   Test R2: 0.9278234231929162
# Elasticnet model (alpha=0.004175, l1_ratio=0.400000):
#   RMSE: 0.11166105834224758
#   Train R2: 0.9280373193056748
#   Test R2: 0.9268385421757681
# Elasticnet model (alpha=0.004894, l1_ratio=0.000000):
#   RMSE: 0.10476131896024755
#   Train R2: 0.9447618735781531
#   Test R2: 0.9356007534580193
# Elasticnet model (alpha=0.004894, l1_ratio=0.040000):
#   RMSE: 0.10460419104193996
#   Train R2: 0.9416879003809632
#   Test R2: 0.9357937890390801
# Elasticnet model (alpha=0.004894, l1_ratio=0.080000):
#   RMSE: 0.10550702979796027
#   Train R2: 0.9390201456525804
#   Test R2: 0.9346806784585354
# Elasticnet model (alpha=0.004894, l1_ratio=0.120000):
#   RMSE: 0.10637465335200194
#   Train R2: 0.9368885019260406
#   Test R2: 0.9336019711558315
# Elasticnet model (alpha=0.004894, l1_ratio=0.160000):
#   RMSE: 0.10733471765949985
#   Train R2: 0.935227478258135
#   Test R2: 0.9323980369290461
# Elasticnet model (alpha=0.004894, l1_ratio=0.200000):
#   RMSE: 0.108416934608312
#   Train R2: 0.9335799616742366
#   Test R2: 0.9310279524939662
# Elasticnet model (alpha=0.004894, l1_ratio=0.240000):
#   RMSE: 0.10952428158230404
#   Train R2: 0.9318381838638625
#   Test R2: 0.9296118262728538
# Elasticnet model (alpha=0.004894, l1_ratio=0.280000):
#   RMSE: 0.11040827825307538
#   Train R2: 0.9302817812741544
#   Test R2: 0.9284710012734492
# Elasticnet model (alpha=0.004894, l1_ratio=0.320000):
#   RMSE: 0.11129836215254604
#   Train R2: 0.9287360544865148
#   Test R2: 0.9273130547124573
# Elasticnet model (alpha=0.004894, l1_ratio=0.360000):
#   RMSE: 0.11211318036371802
#   Train R2: 0.9271826800311633
#   Test R2: 0.926244872836326
# Elasticnet model (alpha=0.004894, l1_ratio=0.400000):
#   RMSE: 0.1129385705755002
#   Train R2: 0.9256144083710428
#   Test R2: 0.9251548876854532
# Elasticnet model (alpha=0.005736, l1_ratio=0.000000):
#   RMSE: 0.10477116849878763
#   Train R2: 0.9442844987250193
#   Test R2: 0.9355886434027951
# Elasticnet model (alpha=0.005736, l1_ratio=0.040000):
#   RMSE: 0.1048915565768789
#   Train R2: 0.9409012078448539
#   Test R2: 0.9354405336767915
# Elasticnet model (alpha=0.005736, l1_ratio=0.080000):
#   RMSE: 0.10598575329314255
#   Train R2: 0.9379798311969536
#   Test R2: 0.9340865789872158
# Elasticnet model (alpha=0.005736, l1_ratio=0.120000):
#   RMSE: 0.10697973233452178
#   Train R2: 0.9357800466191827
#   Test R2: 0.932844453929235
# Elasticnet model (alpha=0.005736, l1_ratio=0.160000):
#   RMSE: 0.10819713828677543
#   Train R2: 0.9339045852553791
#   Test R2: 0.9313073264767315
# Elasticnet model (alpha=0.005736, l1_ratio=0.200000):
#   RMSE: 0.10949286002191327
#   Train R2: 0.9319099757103553
#   Test R2: 0.9296522079847447
# Elasticnet model (alpha=0.005736, l1_ratio=0.240000):
#   RMSE: 0.11055241065929935
#   Train R2: 0.9300631249527207
#   Test R2: 0.9282841244155747
# Elasticnet model (alpha=0.005736, l1_ratio=0.280000):
#   RMSE: 0.11157261484814324
#   Train R2: 0.928270692921162
#   Test R2: 0.9269543944245371
# Elasticnet model (alpha=0.005736, l1_ratio=0.320000):
#   RMSE: 0.11251371391486815
#   Train R2: 0.9264412001334722
#   Test R2: 0.9257169389672223
# Elasticnet model (alpha=0.005736, l1_ratio=0.360000):
#   RMSE: 0.11344586190464291
#   Train R2: 0.9247378656046307
#   Test R2: 0.924481007216952
# Elasticnet model (alpha=0.005736, l1_ratio=0.400000):
#   RMSE: 0.11430250323524573
#   Train R2: 0.9231566469339091
#   Test R2: 0.9233361978789765
# Elasticnet model (alpha=0.006723, l1_ratio=0.000000):
#   RMSE: 0.10480835982759579
#   Train R2: 0.9437889713305113
#   Test R2: 0.9355429062184587
# Elasticnet model (alpha=0.006723, l1_ratio=0.040000):
#   RMSE: 0.10523741816882669
#   Train R2: 0.9400390798003299
#   Test R2: 0.9350140846293539
# Elasticnet model (alpha=0.006723, l1_ratio=0.080000):
#   RMSE: 0.10645278784870989
#   Train R2: 0.9369163750586583
#   Test R2: 0.9335043937397194
# Elasticnet model (alpha=0.006723, l1_ratio=0.120000):
#   RMSE: 0.1077226342178438
#   Train R2: 0.9345907538776399
#   Test R2: 0.9319085157538763
# Elasticnet model (alpha=0.006723, l1_ratio=0.160000):
#   RMSE: 0.10923473982005726
#   Train R2: 0.932311598422138
#   Test R2: 0.9299834950307412
# Elasticnet model (alpha=0.006723, l1_ratio=0.200000):
#   RMSE: 0.11052654746241036
#   Train R2: 0.9301126223873358
#   Test R2: 0.9283176756486655
# Elasticnet model (alpha=0.006723, l1_ratio=0.240000):
#   RMSE: 0.11171697320840263
#   Train R2: 0.9280385488212837
#   Test R2: 0.9267652518553848
# Elasticnet model (alpha=0.006723, l1_ratio=0.280000):
#   RMSE: 0.11281501629946163
#   Train R2: 0.9259016959004934
#   Test R2: 0.9253185585251855
# Elasticnet model (alpha=0.006723, l1_ratio=0.320000):
#   RMSE: 0.11387526114184603
#   Train R2: 0.9239777163828216
#   Test R2: 0.9239082376525474
# Elasticnet model (alpha=0.006723, l1_ratio=0.360000):
#   RMSE: 0.11480456029434342
#   Train R2: 0.9221611140057334
#   Test R2: 0.9226612497033628
# Elasticnet model (alpha=0.006723, l1_ratio=0.400000):
#   RMSE: 0.1155559845885171
#   Train R2: 0.9206847383468895
#   Test R2: 0.9216455339221119
# Elasticnet model (alpha=0.007880, l1_ratio=0.000000):
#   RMSE: 0.10487430301688752
#   Train R2: 0.9432728725980429
#   Test R2: 0.9354617706390549
# Elasticnet model (alpha=0.007880, l1_ratio=0.040000):
#   RMSE: 0.10563851196795025
#   Train R2: 0.9390904818458293
#   Test R2: 0.9345177759957723
# Elasticnet model (alpha=0.007880, l1_ratio=0.080000):
#   RMSE: 0.10699868122775479
#   Train R2: 0.9357561355173676
#   Test R2: 0.9328206618343546
# Elasticnet model (alpha=0.007880, l1_ratio=0.120000):
#   RMSE: 0.10863509549567342
#   Train R2: 0.9331846119217949
#   Test R2: 0.9307500965993708
# Elasticnet model (alpha=0.007880, l1_ratio=0.160000):
#   RMSE: 0.11028655162462668
#   Train R2: 0.9305188739393253
#   Test R2: 0.9286286377152979
# Elasticnet model (alpha=0.007880, l1_ratio=0.200000):
#   RMSE: 0.11166351970649821
#   Train R2: 0.9281197833656103
#   Test R2: 0.9268353167185814
# Elasticnet model (alpha=0.007880, l1_ratio=0.240000):
#   RMSE: 0.11297093506619223
#   Train R2: 0.9256562345884225
#   Test R2: 0.9251119852295817
# Elasticnet model (alpha=0.007880, l1_ratio=0.280000):
#   RMSE: 0.11418399124396243
#   Train R2: 0.9234155374374693
#   Test R2: 0.9234950897580109
# Elasticnet model (alpha=0.007880, l1_ratio=0.320000):
#   RMSE: 0.11519390817724233
#   Train R2: 0.9213846340077659
#   Test R2: 0.9221357873184097
# Elasticnet model (alpha=0.007880, l1_ratio=0.360000):
#   RMSE: 0.11606807968497744
#   Train R2: 0.9197517923145281
#   Test R2: 0.9209495276294425
# Elasticnet model (alpha=0.007880, l1_ratio=0.400000):
#   RMSE: 0.11706354295240291
#   Train R2: 0.9179736407247979
#   Test R2: 0.9195877528185582
# Elasticnet model (alpha=0.009237, l1_ratio=0.000000):
#   RMSE: 0.10497053718954644
#   Train R2: 0.9427332708956806
#   Test R2: 0.9353432738771076
# Elasticnet model (alpha=0.009237, l1_ratio=0.040000):
#   RMSE: 0.10608459014876016
#   Train R2: 0.9380758480012994
#   Test R2: 0.9339635867415842
# Elasticnet model (alpha=0.009237, l1_ratio=0.080000):
#   RMSE: 0.10769778884960522
#   Train R2: 0.9345744856735925
#   Test R2: 0.9319399216495273
# Elasticnet model (alpha=0.009237, l1_ratio=0.120000):
#   RMSE: 0.10967217400676695
#   Train R2: 0.931528512665472
#   Test R2: 0.9294216053313537
# Elasticnet model (alpha=0.009237, l1_ratio=0.160000):
#   RMSE: 0.11133914782675326
#   Train R2: 0.9286293287381474
#   Test R2: 0.9272597721806439
# Elasticnet model (alpha=0.009237, l1_ratio=0.200000):
#   RMSE: 0.11289777103910612
#   Train R2: 0.9258052971463991
#   Test R2: 0.9252089541447149
# Elasticnet model (alpha=0.009237, l1_ratio=0.240000):
#   RMSE: 0.11434239513782168
#   Train R2: 0.9231319828324636
#   Test R2: 0.9232826767659585
# Elasticnet model (alpha=0.009237, l1_ratio=0.280000):
#   RMSE: 0.1154617607566698
#   Train R2: 0.9208732020398025
#   Test R2: 0.921773261587413
# Elasticnet model (alpha=0.009237, l1_ratio=0.320000):
#   RMSE: 0.11650822097621476
#   Train R2: 0.9189437459839068
#   Test R2: 0.9203488569370673
# Elasticnet model (alpha=0.009237, l1_ratio=0.360000):
#   RMSE: 0.11767193466328475
#   Train R2: 0.9169442871078058
#   Test R2: 0.9187497588504663
# Elasticnet model (alpha=0.009237, l1_ratio=0.400000):
#   RMSE: 0.11893291461520965
#   Train R2: 0.9148967645707047
#   Test R2: 0.9169990630328515
# Elasticnet model (alpha=0.010826, l1_ratio=0.000000):
#   RMSE: 0.10509862871871103
#   Train R2: 0.9421667678635137
#   Test R2: 0.9351853813439703
# Elasticnet model (alpha=0.010826, l1_ratio=0.040000):
#   RMSE: 0.10656479921432319
#   Train R2: 0.9370158071605624
#   Test R2: 0.9333643845881028
# Elasticnet model (alpha=0.010826, l1_ratio=0.080000):
#   RMSE: 0.10854475124673936
#   Train R2: 0.9332365715290646
#   Test R2: 0.9308652293565264
# Elasticnet model (alpha=0.010826, l1_ratio=0.120000):
#   RMSE: 0.11071393388346559
#   Train R2: 0.9297062354732957
#   Test R2: 0.9280744095544989
# Elasticnet model (alpha=0.010826, l1_ratio=0.160000):
#   RMSE: 0.11253598258044184
#   Train R2: 0.9264613235383178
#   Test R2: 0.9256875319147996
# Elasticnet model (alpha=0.010826, l1_ratio=0.200000):
#   RMSE: 0.11427768746922874
#   Train R2: 0.9232345451902748
#   Test R2: 0.9233694826173257
# Elasticnet model (alpha=0.010826, l1_ratio=0.240000):
#   RMSE: 0.11560321204982497
#   Train R2: 0.9206119914165349
#   Test R2: 0.9215814742593007
# Elasticnet model (alpha=0.010826, l1_ratio=0.280000):
#   RMSE: 0.1168228563666957
#   Train R2: 0.9183550761240413
#   Test R2: 0.9199180734691093
# Elasticnet model (alpha=0.010826, l1_ratio=0.320000):
#   RMSE: 0.11817586784686655
#   Train R2: 0.916073391231356
#   Test R2: 0.9180523560895902
# Elasticnet model (alpha=0.010826, l1_ratio=0.360000):
#   RMSE: 0.11963026678821015
#   Train R2: 0.9137074460629625
#   Test R2: 0.9160228728242107
# Elasticnet model (alpha=0.010826, l1_ratio=0.400000):
#   RMSE: 0.12019842981249927
#   Train R2: 0.9125421426302202
#   Test R2: 0.9152233092791509
# Elasticnet model (alpha=0.012690, l1_ratio=0.000000):
#   RMSE: 0.10526005706576408
#   Train R2: 0.9415695749408217
#   Test R2: 0.9349861218056565
# Elasticnet model (alpha=0.012690, l1_ratio=0.040000):
#   RMSE: 0.10710475049156155
#   Train R2: 0.9358996601935763
#   Test R2: 0.9326874042139004
# Elasticnet model (alpha=0.012690, l1_ratio=0.080000):
#   RMSE: 0.10954012284112297
#   Train R2: 0.9316721046707912
#   Test R2: 0.9295914633378134
# Elasticnet model (alpha=0.012690, l1_ratio=0.120000):
#   RMSE: 0.11181305494312437
#   Train R2: 0.9277207492623419
#   Test R2: 0.9266392271823637
# Elasticnet model (alpha=0.012690, l1_ratio=0.160000):
#   RMSE: 0.11385447984765394
#   Train R2: 0.9239582941647018
#   Test R2: 0.9239360073541898
# Elasticnet model (alpha=0.012690, l1_ratio=0.200000):
#   RMSE: 0.11556584736903891
#   Train R2: 0.9206931304433914
#   Test R2: 0.9216321581392171
# Elasticnet model (alpha=0.012690, l1_ratio=0.240000):
#   RMSE: 0.11695444428174129
#   Train R2: 0.9180897916977926
#   Test R2: 0.9197375651523509
# Elasticnet model (alpha=0.012690, l1_ratio=0.280000):
#   RMSE: 0.11851163617187258
#   Train R2: 0.9154668395434663
#   Test R2: 0.9175860254779893
# Elasticnet model (alpha=0.012690, l1_ratio=0.320000):
#   RMSE: 0.11991160284641217
#   Train R2: 0.9131556881754515
#   Test R2: 0.9156274281743301
# Elasticnet model (alpha=0.012690, l1_ratio=0.360000):
#   RMSE: 0.12045663717890043
#   Train R2: 0.9118451961926612
#   Test R2: 0.9148586875810832
# Elasticnet model (alpha=0.012690, l1_ratio=0.400000):
#   RMSE: 0.12102376454977462
#   Train R2: 0.9104821648628837
#   Test R2: 0.9140550849157457
# Elasticnet model (alpha=0.014874, l1_ratio=0.000000):
#   RMSE: 0.10545609787129123
#   Train R2: 0.9409376206234419
#   Test R2: 0.9347437270707568
# Elasticnet model (alpha=0.014874, l1_ratio=0.040000):
#   RMSE: 0.10771124434634569
#   Train R2: 0.9346689973793503
#   Test R2: 0.9319229140697066
# Elasticnet model (alpha=0.014874, l1_ratio=0.080000):
#   RMSE: 0.11058397413236061
#   Train R2: 0.9298969297254884
#   Test R2: 0.9282431678189604
# Elasticnet model (alpha=0.014874, l1_ratio=0.120000):
#   RMSE: 0.11301611076248094
#   Train R2: 0.9254950951613271
#   Test R2: 0.9250520796504562
# Elasticnet model (alpha=0.014874, l1_ratio=0.160000):
#   RMSE: 0.11521321374436687
#   Train R2: 0.9213502576489402
#   Test R2: 0.9221096863071416
# Elasticnet model (alpha=0.014874, l1_ratio=0.200000):
#   RMSE: 0.116849174989675
#   Train R2: 0.9182488878203553
#   Test R2: 0.9198819866362827
# Elasticnet model (alpha=0.014874, l1_ratio=0.240000):
#   RMSE: 0.1186113936728686
#   Train R2: 0.9152386596717074
#   Test R2: 0.9174472226969381
# Elasticnet model (alpha=0.014874, l1_ratio=0.280000):
#   RMSE: 0.12005104912782627
#   Train R2: 0.9127924597605245
#   Test R2: 0.9154310788272478
# Elasticnet model (alpha=0.014874, l1_ratio=0.320000):
#   RMSE: 0.12068830209159094
#   Train R2: 0.9112393452756157
#   Test R2: 0.91453088128937
# Elasticnet model (alpha=0.014874, l1_ratio=0.360000):
#   RMSE: 0.12137252983729613
#   Train R2: 0.9096794407660739
#   Test R2: 0.9135590204706503
# Elasticnet model (alpha=0.014874, l1_ratio=0.400000):
#   RMSE: 0.12200283448933794
#   Train R2: 0.9083782643546793
#   Test R2: 0.9126588888916811
# Elasticnet model (alpha=0.017433, l1_ratio=0.000000):
#   RMSE: 0.10568771539189518
#   Train R2: 0.9402666855197356
#   Test R2: 0.9344567622629035
# Elasticnet model (alpha=0.017433, l1_ratio=0.040000):
#   RMSE: 0.10841460051980524
#   Train R2: 0.9333377110037566
#   Test R2: 0.9310309222353821
# Elasticnet model (alpha=0.017433, l1_ratio=0.080000):
#   RMSE: 0.11162968493350717
#   Train R2: 0.9279684117005449
#   Test R2: 0.9268796487512526
# Elasticnet model (alpha=0.017433, l1_ratio=0.120000):
#   RMSE: 0.11436144607761732
#   Train R2: 0.9229649666912361
#   Test R2: 0.9232571104156987
# Elasticnet model (alpha=0.017433, l1_ratio=0.160000):
#   RMSE: 0.11644148532724244
#   Train R2: 0.9189401023145816
#   Test R2: 0.9204400787977333
# Elasticnet model (alpha=0.017433, l1_ratio=0.200000):
#   RMSE: 0.11841500429256435
#   Train R2: 0.9154959616297302
#   Test R2: 0.9177203679059984
# Elasticnet model (alpha=0.017433, l1_ratio=0.240000):
#   RMSE: 0.12009045896096057
#   Train R2: 0.9126382230613612
#   Test R2: 0.9153755458828511
# Elasticnet model (alpha=0.017433, l1_ratio=0.280000):
#   RMSE: 0.12085730512224815
#   Train R2: 0.9108026677120623
#   Test R2: 0.9142913443437755
# Elasticnet model (alpha=0.017433, l1_ratio=0.320000):
#   RMSE: 0.12166769601564488
#   Train R2: 0.9090430536665088
#   Test R2: 0.9131380771493166
# Elasticnet model (alpha=0.017433, l1_ratio=0.360000):
#   RMSE: 0.12233393526040597
#   Train R2: 0.907648310587472
#   Test R2: 0.912184179426527
# Elasticnet model (alpha=0.017433, l1_ratio=0.400000):
#   RMSE: 0.12301964693192419
#   Train R2: 0.9061815927089522
#   Test R2: 0.9111969619936723
# Elasticnet model (alpha=0.020434, l1_ratio=0.000000):
#   RMSE: 0.10595547834486496
#   Train R2: 0.9395525585942083
#   Test R2: 0.9341242300929152
# Elasticnet model (alpha=0.020434, l1_ratio=0.040000):
#   RMSE: 0.10924253129822507
#   Train R2: 0.93195178328211
#   Test R2: 0.9299735064222351
# Elasticnet model (alpha=0.020434, l1_ratio=0.080000):
#   RMSE: 0.11276781377162358
#   Train R2: 0.9258533806995981
#   Test R2: 0.9253810398412817
# Elasticnet model (alpha=0.020434, l1_ratio=0.120000):
#   RMSE: 0.1156799331016081
#   Train R2: 0.9203622641384488
#   Test R2: 0.9214773534815329
# Elasticnet model (alpha=0.020434, l1_ratio=0.160000):
#   RMSE: 0.1178824749842099
#   Train R2: 0.9163177503387476
#   Test R2: 0.9184587505407802
# Elasticnet model (alpha=0.020434, l1_ratio=0.200000):
#   RMSE: 0.12000138243064808
#   Train R2: 0.9127641921577824
#   Test R2: 0.9155010389013646
# Elasticnet model (alpha=0.020434, l1_ratio=0.240000):
#   RMSE: 0.12092076019279033
#   Train R2: 0.9106268841207013
#   Test R2: 0.914201319557227
# Elasticnet model (alpha=0.020434, l1_ratio=0.280000):
#   RMSE: 0.12186799628518302
#   Train R2: 0.9086406538393366
#   Test R2: 0.9128518419597372
# Elasticnet model (alpha=0.020434, l1_ratio=0.320000):
#   RMSE: 0.12263240826420473
#   Train R2: 0.9070171288230071
#   Test R2: 0.9117551467733764
# Elasticnet model (alpha=0.020434, l1_ratio=0.360000):
#   RMSE: 0.12348575549017514
#   Train R2: 0.9052385939296295
#   Test R2: 0.910522756340325
# Elasticnet model (alpha=0.020434, l1_ratio=0.400000):
#   RMSE: 0.12446709354319642
#   Train R2: 0.9032541787469837
#   Test R2: 0.9090949588526175
# Elasticnet model (alpha=0.023950, l1_ratio=0.000000):
#   RMSE: 0.1062595141263108
#   Train R2: 0.9387912041642489
#   Test R2: 0.9337456309456281
# Elasticnet model (alpha=0.023950, l1_ratio=0.040000):
#   RMSE: 0.11019966022318667
#   Train R2: 0.9303638681014078
#   Test R2: 0.9287410560399523
# Elasticnet model (alpha=0.023950, l1_ratio=0.080000):
#   RMSE: 0.11403377851678337
#   Train R2: 0.9234623408629522
#   Test R2: 0.9236962467158125
# Elasticnet model (alpha=0.023950, l1_ratio=0.120000):
#   RMSE: 0.11689783681203163
#   Train R2: 0.9179700715747993
#   Test R2: 0.9198152424707657
# Elasticnet model (alpha=0.023950, l1_ratio=0.160000):
#   RMSE: 0.11954571747336545
#   Train R2: 0.9134492571828399
#   Test R2: 0.9161415334224218
# Elasticnet model (alpha=0.023950, l1_ratio=0.200000):
#   RMSE: 0.12083418234543414
#   Train R2: 0.9108081133966599
#   Test R2: 0.9143241372730855
# Elasticnet model (alpha=0.023950, l1_ratio=0.240000):
#   RMSE: 0.12194418229597646
#   Train R2: 0.9084750773265576
#   Test R2: 0.9127428462258222
# Elasticnet model (alpha=0.023950, l1_ratio=0.280000):
#   RMSE: 0.12285660550819262
#   Train R2: 0.9065641316238001
#   Test R2: 0.9114321923764133
# Elasticnet model (alpha=0.023950, l1_ratio=0.320000):
#   RMSE: 0.12389557286104211
#   Train R2: 0.9044431536731596
#   Test R2: 0.9099278670492469
# Elasticnet model (alpha=0.023950, l1_ratio=0.360000):
#   RMSE: 0.12495373720547216
#   Train R2: 0.9025563699741175
#   Test R2: 0.9083827249143104
# Elasticnet model (alpha=0.023950, l1_ratio=0.400000):
#   RMSE: 0.1255271093440388
#   Train R2: 0.9018652789972739
#   Test R2: 0.9075399919556747
# Elasticnet model (alpha=0.028072, l1_ratio=0.000000):
#   RMSE: 0.10659951570701537
#   Train R2: 0.9379789255714363
#   Test R2: 0.9333209606489994
# Elasticnet model (alpha=0.028072, l1_ratio=0.040000):
#   RMSE: 0.11122235817958688
#   Train R2: 0.9285809335902159
#   Test R2: 0.9274122944536286
# Elasticnet model (alpha=0.028072, l1_ratio=0.080000):
#   RMSE: 0.11540765321893649
#   Train R2: 0.9208925881987452
#   Test R2: 0.9218465614300935
# Elasticnet model (alpha=0.028072, l1_ratio=0.120000):
#   RMSE: 0.11834856157688861
#   Train R2: 0.9153809270902359
#   Test R2: 0.9178126762836177
# Elasticnet model (alpha=0.028072, l1_ratio=0.160000):
#   RMSE: 0.12054001534037494
#   Train R2: 0.9114442633188476
#   Test R2: 0.9147407798734966
# Elasticnet model (alpha=0.028072, l1_ratio=0.200000):
#   RMSE: 0.12184619394290017
#   Train R2: 0.9086338435307361
#   Test R2: 0.9128830210070599
# Elasticnet model (alpha=0.028072, l1_ratio=0.240000):
#   RMSE: 0.12295831639951744
#   Train R2: 0.906379698617428
#   Test R2: 0.911285484113845
# Elasticnet model (alpha=0.028072, l1_ratio=0.280000):
#   RMSE: 0.12419189039159927
#   Train R2: 0.9039008439070134
#   Test R2: 0.9094965058925593
# Elasticnet model (alpha=0.028072, l1_ratio=0.320000):
#   RMSE: 0.1252529054343795
#   Train R2: 0.9022156513450619
#   Test R2: 0.9079434937194114
# Elasticnet model (alpha=0.028072, l1_ratio=0.360000):
#   RMSE: 0.12592240258754958
#   Train R2: 0.9014049845003814
#   Test R2: 0.9069567495947675
# Elasticnet model (alpha=0.028072, l1_ratio=0.400000):
#   RMSE: 0.12666721443400344
#   Train R2: 0.9005068819196081
#   Test R2: 0.905852821106427
# Elasticnet model (alpha=0.032903, l1_ratio=0.000000):
#   RMSE: 0.10697481284161128
#   Train R2: 0.9371125085261699
#   Test R2: 0.9328506301203597
# Elasticnet model (alpha=0.032903, l1_ratio=0.040000):
#   RMSE: 0.11229333223423192
#   Train R2: 0.9266133005047189
#   Test R2: 0.9260076518521492
# Elasticnet model (alpha=0.032903, l1_ratio=0.080000):
#   RMSE: 0.11657762428143645
#   Train R2: 0.9184365181321604
#   Test R2: 0.9202539331786894
# Elasticnet model (alpha=0.032903, l1_ratio=0.120000):
#   RMSE: 0.11990103885355917
#   Train R2: 0.9126640750637974
#   Test R2: 0.9156422936579556
# Elasticnet model (alpha=0.032903, l1_ratio=0.160000):
#   RMSE: 0.12150559682580585
#   Train R2: 0.9093026577421746
#   Test R2: 0.9133693771270379
# Elasticnet model (alpha=0.032903, l1_ratio=0.200000):
#   RMSE: 0.12288099280691801
#   Train R2: 0.9065671145951546
#   Test R2: 0.9113970270884199
# Elasticnet model (alpha=0.032903, l1_ratio=0.240000):
#   RMSE: 0.12430949895567416
#   Train R2: 0.9037288499240496
#   Test R2: 0.909325012796996
# Elasticnet model (alpha=0.032903, l1_ratio=0.280000):
#   RMSE: 0.12546990956577292
#   Train R2: 0.9019721442000316
#   Test R2: 0.9076242364988556
# Elasticnet model (alpha=0.032903, l1_ratio=0.320000):
#   RMSE: 0.12628051011610725
#   Train R2: 0.9009924940780659
#   Test R2: 0.9064267904137129
# Elasticnet model (alpha=0.032903, l1_ratio=0.360000):
#   RMSE: 0.1271945523947762
#   Train R2: 0.8998907164657297
#   Test R2: 0.9050672867129177
# Elasticnet model (alpha=0.032903, l1_ratio=0.400000):
#   RMSE: 0.1282114254709594
#   Train R2: 0.8986652294295954
#   Test R2: 0.9035433158016721
# Elasticnet model (alpha=0.038566, l1_ratio=0.000000):
#   RMSE: 0.10738451418198382
#   Train R2: 0.9361893257900515
#   Test R2: 0.9323352963054619
# Elasticnet model (alpha=0.038566, l1_ratio=0.040000):
#   RMSE: 0.11340047310415463
#   Train R2: 0.9244795459788173
#   Test R2: 0.9245414242429716
# Elasticnet model (alpha=0.038566, l1_ratio=0.080000):
#   RMSE: 0.11786243890644975
#   Train R2: 0.9160236937032966
#   Test R2: 0.9184864667551231
# Elasticnet model (alpha=0.038566, l1_ratio=0.120000):
#   RMSE: 0.120832378182128
#   Train R2: 0.9107254982075906
#   Test R2: 0.9143266956897651
# Elasticnet model (alpha=0.038566, l1_ratio=0.160000):
#   RMSE: 0.12257263231522549
#   Train R2: 0.9072270488196716
#   Test R2: 0.9118411539604677
# Elasticnet model (alpha=0.038566, l1_ratio=0.200000):
#   RMSE: 0.12418307110669369
#   Train R2: 0.9040413493100812
#   Test R2: 0.9095093593527389
# Elasticnet model (alpha=0.038566, l1_ratio=0.240000):
#   RMSE: 0.12559453391993594
#   Train R2: 0.9018439811116997
#   Test R2: 0.9074406388976425
# Elasticnet model (alpha=0.038566, l1_ratio=0.280000):
#   RMSE: 0.12656067611583227
#   Train R2: 0.9006766450350994
#   Test R2: 0.906011126694309
# Elasticnet model (alpha=0.038566, l1_ratio=0.320000):
#   RMSE: 0.12766552834865244
#   Train R2: 0.8993441383183344
#   Test R2: 0.9043629514668395
# Elasticnet model (alpha=0.038566, l1_ratio=0.360000):
#   RMSE: 0.12890802026226444
#   Train R2: 0.8978439859386343
#   Test R2: 0.9024923368533236
# Elasticnet model (alpha=0.038566, l1_ratio=0.400000):
#   RMSE: 0.13028674576613888
#   Train R2: 0.8961736607163929
#   Test R2: 0.900395411803511
# Elasticnet model (alpha=0.045204, l1_ratio=0.000000):
#   RMSE: 0.1078277193137741
#   Train R2: 0.9352073861509997
#   Test R2: 0.9317756023637094
# Elasticnet model (alpha=0.045204, l1_ratio=0.040000):
#   RMSE: 0.11454273408398952
#   Train R2: 0.9222183347086385
#   Test R2: 0.9230136089006463
# Elasticnet model (alpha=0.045204, l1_ratio=0.080000):
#   RMSE: 0.11929407091363343
#   Train R2: 0.913503040308266
#   Test R2: 0.9164942099419796
# Elasticnet model (alpha=0.045204, l1_ratio=0.120000):
#   RMSE: 0.12188038966890212
#   Train R2: 0.90854007984647
#   Test R2: 0.9128341159690853
# Elasticnet model (alpha=0.045204, l1_ratio=0.160000):
#   RMSE: 0.12376059960466809
#   Train R2: 0.9049258849605653
#   Test R2: 0.9101240113770148
# Elasticnet model (alpha=0.045204, l1_ratio=0.200000):
#   RMSE: 0.12558535714523003
#   Train R2: 0.901881648261067
#   Test R2: 0.9074541644125826
# Elasticnet model (alpha=0.045204, l1_ratio=0.240000):
#   RMSE: 0.12671344448621444
#   Train R2: 0.9005171287801457
#   Test R2: 0.9057840862996547
# Elasticnet model (alpha=0.045204, l1_ratio=0.280000):
#   RMSE: 0.12802491725197504
#   Train R2: 0.8989337191928599
#   Test R2: 0.9038237413468746
# Elasticnet model (alpha=0.045204, l1_ratio=0.320000):
#   RMSE: 0.12952009241434778
#   Train R2: 0.8971241841517984
#   Test R2: 0.9015641802742924
# Elasticnet model (alpha=0.045204, l1_ratio=0.360000):
#   RMSE: 0.13105999876850982
#   Train R2: 0.8952408706973489
#   Test R2: 0.8992095950534085
# Elasticnet model (alpha=0.045204, l1_ratio=0.400000):
#   RMSE: 0.13206827097964002
#   Train R2: 0.8940998653805157
#   Test R2: 0.897652826039527
# Elasticnet model (alpha=0.052983, l1_ratio=0.000000):
#   RMSE: 0.10830378998938252
#   Train R2: 0.9341653153036719
#   Test R2: 0.9311718367313028
# Elasticnet model (alpha=0.052983, l1_ratio=0.040000):
#   RMSE: 0.1158548638494428
#   Train R2: 0.9197818983863433
#   Test R2: 0.9212396906355917
# Elasticnet model (alpha=0.052983, l1_ratio=0.080000):
#   RMSE: 0.12057874750908251
#   Train R2: 0.9111990934945905
#   Test R2: 0.9146859797304014
# Elasticnet model (alpha=0.052983, l1_ratio=0.120000):
#   RMSE: 0.1229910986515123
#   Train R2: 0.9064871922152019
#   Test R2: 0.9112381729698682
# Elasticnet model (alpha=0.052983, l1_ratio=0.160000):
#   RMSE: 0.1252497342896993
#   Train R2: 0.9023402972690341
#   Test R2: 0.9079481550213381
# Elasticnet model (alpha=0.052983, l1_ratio=0.200000):
#   RMSE: 0.1266845404747978
#   Train R2: 0.9005799424693895
#   Test R2: 0.9058270637006088
# Elasticnet model (alpha=0.052983, l1_ratio=0.240000):
#   RMSE: 0.12820676144773846
#   Train R2: 0.8987397738603305
#   Test R2: 0.9035503333982796
# Elasticnet model (alpha=0.052983, l1_ratio=0.280000):
#   RMSE: 0.12997356291899612
#   Train R2: 0.8965963075809232
#   Test R2: 0.9008736946216246
# Elasticnet model (alpha=0.052983, l1_ratio=0.320000):
#   RMSE: 0.13160804338733803
#   Train R2: 0.894581451600284
#   Test R2: 0.8983648959643459
# Elasticnet model (alpha=0.052983, l1_ratio=0.360000):
#   RMSE: 0.13275908556012053
#   Train R2: 0.893336960247493
#   Test R2: 0.8965793231647251
# Elasticnet model (alpha=0.052983, l1_ratio=0.400000):
#   RMSE: 0.13398356503373157
#   Train R2: 0.8919583012857847
#   Test R2: 0.8946627612988249
# Elasticnet model (alpha=0.062102, l1_ratio=0.000000):
#   RMSE: 0.10881265905689548
#   Train R2: 0.933062264132295
#   Test R2: 0.9305235342993045
# Elasticnet model (alpha=0.062102, l1_ratio=0.040000):
#   RMSE: 0.11711415382666528
#   Train R2: 0.9173105901215689
#   Test R2: 0.9195182074455676
# Elasticnet model (alpha=0.062102, l1_ratio=0.080000):
#   RMSE: 0.12158984190858675
#   Train R2: 0.9091265498911516
#   Test R2: 0.9132492059700513
# Elasticnet model (alpha=0.062102, l1_ratio=0.120000):
#   RMSE: 0.12427591484733698
#   Train R2: 0.9041168928427378
#   Test R2: 0.9093740006420188
# Elasticnet model (alpha=0.062102, l1_ratio=0.160000):
#   RMSE: 0.12642331525881736
#   Train R2: 0.9009271966654102
#   Test R2: 0.9062150349938929
# Elasticnet model (alpha=0.062102, l1_ratio=0.200000):
#   RMSE: 0.12813994997776418
#   Train R2: 0.8988495924061435
#   Test R2: 0.9036508314513976
# Elasticnet model (alpha=0.062102, l1_ratio=0.240000):
#   RMSE: 0.13018153410931377
#   Train R2: 0.8963678909684673
#   Test R2: 0.9005562160719817
# Elasticnet model (alpha=0.062102, l1_ratio=0.280000):
#   RMSE: 0.13200357840491736
#   Train R2: 0.8941487552034342
#   Test R2: 0.8977530693531299
# Elasticnet model (alpha=0.062102, l1_ratio=0.320000):
#   RMSE: 0.13337641753320434
#   Train R2: 0.8926361855279686
#   Test R2: 0.8956152711734984
# Elasticnet model (alpha=0.062102, l1_ratio=0.360000):
#   RMSE: 0.13484547202940309
#   Train R2: 0.890942635347871
#   Test R2: 0.8933031478460247
# Elasticnet model (alpha=0.062102, l1_ratio=0.400000):
#   RMSE: 0.1364149401764176
#   Train R2: 0.8890626750370243
#   Test R2: 0.8908050019730885
# Elasticnet model (alpha=0.072790, l1_ratio=0.000000):
#   RMSE: 0.10935514574891297
#   Train R2: 0.9318977496418702
#   Test R2: 0.9298290560929057
# Elasticnet model (alpha=0.072790, l1_ratio=0.040000):
#   RMSE: 0.11825862133486326
#   Train R2: 0.915020723091882
#   Test R2: 0.917937547070276
# Elasticnet model (alpha=0.072790, l1_ratio=0.080000):
#   RMSE: 0.12276608131721134
#   Train R2: 0.9070095152255078
#   Test R2: 0.9115626627785353
# Elasticnet model (alpha=0.072790, l1_ratio=0.120000):
#   RMSE: 0.12578937454721306
#   Train R2: 0.9017312857839919
#   Test R2: 0.9071532328751671
# Elasticnet model (alpha=0.072790, l1_ratio=0.160000):
#   RMSE: 0.1277597019080924
#   Train R2: 0.899343102630726
#   Test R2: 0.9042218044674125
# Elasticnet model (alpha=0.072790, l1_ratio=0.200000):
#   RMSE: 0.13005216964912114
#   Train R2: 0.8965535051807283
#   Test R2: 0.9007537571386328
# Elasticnet model (alpha=0.072790, l1_ratio=0.240000):
#   RMSE: 0.13223954322957404
#   Train R2: 0.893880839308082
#   Test R2: 0.8973871968011399
# Elasticnet model (alpha=0.072790, l1_ratio=0.280000):
#   RMSE: 0.13385950343166178
#   Train R2: 0.8920727913822077
#   Test R2: 0.894857744262769
# Elasticnet model (alpha=0.072790, l1_ratio=0.320000):
#   RMSE: 0.13560942794562625
#   Train R2: 0.8900196198894064
#   Test R2: 0.8920907587445949
# Elasticnet model (alpha=0.072790, l1_ratio=0.360000):
#   RMSE: 0.1374923090304469
#   Train R2: 0.887714417465131
#   Test R2: 0.8890734050172443
# Elasticnet model (alpha=0.072790, l1_ratio=0.400000):
#   RMSE: 0.1395026074595406
#   Train R2: 0.885154265515396
#   Test R2: 0.8858059380698927
# Elasticnet model (alpha=0.085317, l1_ratio=0.000000):
#   RMSE: 0.10993323946983245
#   Train R2: 0.9306714430709208
#   Test R2: 0.9290851934432263
# Elasticnet model (alpha=0.085317, l1_ratio=0.040000):
#   RMSE: 0.1195850721813179
#   Train R2: 0.9126675340925079
#   Test R2: 0.9160863115583194
# Elasticnet model (alpha=0.085317, l1_ratio=0.080000):
#   RMSE: 0.12400839606583393
#   Train R2: 0.9048332998162315
#   Test R2: 0.9097637473234365
# Elasticnet model (alpha=0.085317, l1_ratio=0.120000):
#   RMSE: 0.12702787175899294
#   Train R2: 0.9002676175184645
#   Test R2: 0.9053159306506334
# Elasticnet model (alpha=0.085317, l1_ratio=0.160000):
#   RMSE: 0.12950408918010795
#   Train R2: 0.8972546851360981
#   Test R2: 0.9015885038233483
# Elasticnet model (alpha=0.085317, l1_ratio=0.200000):
#   RMSE: 0.1322479926821744
#   Train R2: 0.8938566005650823
#   Test R2: 0.897374083481253
# Elasticnet model (alpha=0.085317, l1_ratio=0.240000):
#   RMSE: 0.13413326026551178
#   Train R2: 0.8917403347214015
#   Test R2: 0.8944272504561308
# Elasticnet model (alpha=0.085317, l1_ratio=0.280000):
#   RMSE: 0.13619490900043635
#   Train R2: 0.8892933404339255
#   Test R2: 0.8911569711506759
# Elasticnet model (alpha=0.085317, l1_ratio=0.320000):
#   RMSE: 0.1384319904635605
#   Train R2: 0.8865075613781975
#   Test R2: 0.8875519838104946
# Elasticnet model (alpha=0.085317, l1_ratio=0.360000):
#   RMSE: 0.14083812418107142
#   Train R2: 0.8833773485340557
#   Test R2: 0.8836090172557977
# Elasticnet model (alpha=0.085317, l1_ratio=0.400000):
#   RMSE: 0.14340851176632727
#   Train R2: 0.8798960806478933
#   Test R2: 0.8793218263828124
# Elasticnet model (alpha=0.100000, l1_ratio=0.000000):
#   RMSE: 0.11055031296355883
#   Train R2: 0.9293829261700646
#   Test R2: 0.9282868459601994
# Elasticnet model (alpha=0.100000, l1_ratio=0.040000):
#   RMSE: 0.12093389270504226
#   Train R2: 0.9103689739112854
#   Test R2: 0.9141826823371935
# Elasticnet model (alpha=0.100000, l1_ratio=0.080000):
#   RMSE: 0.1254825621737494
#   Train R2: 0.9023461671666242
#   Test R2: 0.9076056048881723
# Elasticnet model (alpha=0.100000, l1_ratio=0.120000):
#   RMSE: 0.12849282110976734
#   Train R2: 0.8985258884223465
#   Test R2: 0.9031194491136584
# Elasticnet model (alpha=0.100000, l1_ratio=0.160000):
#   RMSE: 0.13175608485737908
#   Train R2: 0.89451679395615
#   Test R2: 0.8981361155295013
# Elasticnet model (alpha=0.100000, l1_ratio=0.200000):
#   RMSE: 0.13411387285185705
#   Train R2: 0.8917430843446141
#   Test R2: 0.8944577668939275
# Elasticnet model (alpha=0.100000, l1_ratio=0.240000):
#   RMSE: 0.13650712119833547
#   Train R2: 0.8888896013003086
#   Test R2: 0.8906573772716692
# Elasticnet model (alpha=0.100000, l1_ratio=0.280000):
#   RMSE: 0.13913345676242111
#   Train R2: 0.885582734207346
#   Test R2: 0.8864094972930865
# Elasticnet model (alpha=0.100000, l1_ratio=0.320000):
#   RMSE: 0.14198386204850566
#   Train R2: 0.8818133235266474
#   Test R2: 0.8817076005468434
# Elasticnet model (alpha=0.100000, l1_ratio=0.360000):
#   RMSE: 0.1450508564814967
#   Train R2: 0.8775710806214098
#   Test R2: 0.8765419349419926
# Elasticnet model (alpha=0.100000, l1_ratio=0.400000):
#   RMSE: 0.14803930923497813
#   Train R2: 0.8732104579099917
#   Test R2: 0.8714023681825562
