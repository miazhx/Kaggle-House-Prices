# %%
import numpy as np
import pandas as pd

from math import sqrt
from scipy import stats
from scipy.stats import norm

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import ElasticNet

import mlflow
import mlflow.sklearn

import os
import warnings
import sys

import logging
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

from data_processing import data_process

def train_linear( ):

    
    #from data_processing import data_process

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        r2 = r2_score(actual, pred)
        return rmse, r2


    warnings.filterwarnings("ignore")
    np.random.seed(40)

#     # Read the file
#     try:
#         df_raw = pd.read_csv('train.csv',index_col=0)
#     except Exception as e:
#         logger.exception(
#             "Unable to download training & test CSV, check your internet connection. Error: %s", e)
        
    # Data processing.
    df_processed = data_process()
    
    # The predicted column is "SalePrice" , split the data into training and test sets. (0.75, 0.25) split.
    x_m = df_processed.drop(["SalePrice"], axis=1)
    y_m = df_processed.loc[:,'SalePrice']
    X_train, X_test, y_train, y_test = train_test_split(x_m, y_m, test_size=0.2, random_state=42)
      
    
    # Execute linear regression
    with mlflow.start_run():
        ols = LinearRegression()
        ols.fit(X_train, y_train)

        # Evaluate Metrics
        rmse = sqrt(mean_squared_error(y_test, ols.predict(X_test)))

        # Print out metrics
        print("R^2 for train set: %f" %ols.score(X_train, y_train))
        print('-'*50)
        print("R^2 for test  set: %f" %ols.score(X_test, y_test))
        print('-'*50)
        print("RMSE for test  set: %f" %rmse)

        # Log parameter, metrics, and model to MLflow
        mlflow.log_param("model", 'linear_regression')
        mlflow.log_metric("r2_train", ols.score(X_train, y_train))
        mlflow.log_metric("r2_test", ols.score(X_test, y_test))
        mlflow.log_metric("rmse", rmse)



        mlflow.sklearn.log_model(ols, "model")
        
def train_elasticnet(N_alpha, N_rho):


    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        r2_test = r2_score(actual, pred)
        return rmse, r2_test


    warnings.filterwarnings("ignore")
    np.random.seed(40)

#     # Read the file
#     try:
#         df_raw = pd.read_csv('train.csv',index_col=0)
#     except Exception as e:
#         logger.exception(
#             "Unable to download training & test CSV, check your internet connection. Error: %s", e)
        
    # Data processing.
    df_processed = data_process()
    
    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(df_processed)

    # The predicted column is "SalePrice" .
    train_x = train.drop(["SalePrice"], axis=1)
    test_x = test.drop(["SalePrice"], axis=1)
    train_y = train[["SalePrice"]]
    test_y = test[["SalePrice"]]

    # Set default values if no N_alpha is provided
    if int(N_alpha) is None:
        N_alpha = 50
    else:
        N_alpha = int(N_alpha)

    # Set default values if no N_rho is provided
    if int(N_rho) is None:
        N_rho = 11
    else:
        N_rho = int(N_rho)
    
    alphaRange = np.logspace(-3, -1, N_alpha)
    rhoRange   = np.linspace(0,0.4, N_rho) # we avoid very small rho by starting at 0.1
    scores     = np.zeros((N_rho, N_alpha))
      
    
    # Execute ElasticNet
    for alphaIdx, alpha in enumerate(alphaRange):
        for rhoIdx, rho in enumerate(rhoRange):
            with mlflow.start_run():
                lr = ElasticNet(alpha=alpha, l1_ratio=rho, normalize=False)
                lr.fit(train_x, train_y)
                r2_train = lr.score(train_x, train_y)
        
        # Training Model Performances Evaluate Metrics
#         predicted_qualities = lr.predict(test_x)
#         (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)        

        # Evaluate Metrics
                predicted_qualities = lr.predict(test_x)
                (rmse, r2_test) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
                print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, rho))
                print("  RMSE: %s" % rmse)
                print("  Train R2: %s" % r2_train)
                print("  Test R2: %s" % r2_test)

        # Log parameter, metrics, and model to MLflow
                mlflow.log_param("model", 'elasticnet')
                mlflow.log_param("alpha", alpha)
                mlflow.log_param("l1_ratio", rho)
                mlflow.log_metric("rmse", rmse)
                mlflow.log_metric("r2_test", r2_test)
                mlflow.log_metric("r2_train", r2_train)
                #mlflow.log_metric("mae", mae)

                mlflow.sklearn.log_model(lr, "model")

# %%
train_linear()
# Out:
# R^2 for train set: 0.950989
# --------------------------------------------------
# R^2 for test  set: 0.932012
# --------------------------------------------------
# RMSE for test  set: 0.102994

# %%
train_elasticnet(20, 11)
# Out:
# Elasticnet model (alpha=0.001000, l1_ratio=0.000000):
#   RMSE: 0.10593779187074763
#   Train R2: 0.9485381598000583
#   Test R2: 0.9341462207039796
# Elasticnet model (alpha=0.001000, l1_ratio=0.040000):
#   RMSE: 0.10464164491923487
#   Train R2: 0.9474663260992879
#   Test R2: 0.9357478023144344
# Elasticnet model (alpha=0.001000, l1_ratio=0.080000):
#   RMSE: 0.10401549533779379
#   Train R2: 0.9462576249320056
#   Test R2: 0.9365144400925878
# Elasticnet model (alpha=0.001000, l1_ratio=0.120000):
#   RMSE: 0.10383483216991975
#   Train R2: 0.9451836102614231
#   Test R2: 0.936734783065811
# Elasticnet model (alpha=0.001000, l1_ratio=0.160000):
#   RMSE: 0.10387892779448114
#   Train R2: 0.9443021571992521
#   Test R2: 0.9366810378716096
# Elasticnet model (alpha=0.001000, l1_ratio=0.200000):
#   RMSE: 0.10411895407472008
#   Train R2: 0.9434997991328457
#   Test R2: 0.9363880857968322
# Elasticnet model (alpha=0.001000, l1_ratio=0.240000):
#   RMSE: 0.10449243317931145
#   Train R2: 0.9427199500644328
#   Test R2: 0.9359309100415534
# Elasticnet model (alpha=0.001000, l1_ratio=0.280000):
#   RMSE: 0.10452204015067819
#   Train R2: 0.9421537182061154
#   Test R2: 0.9358945981213962
# Elasticnet model (alpha=0.001000, l1_ratio=0.320000):
#   RMSE: 0.10459382559688611
#   Train R2: 0.9415045259675383
#   Test R2: 0.9358065130603842
# Elasticnet model (alpha=0.001000, l1_ratio=0.360000):
#   RMSE: 0.10470576236368143
#   Train R2: 0.9408086538145198
#   Test R2: 0.9356690392396768
# Elasticnet model (alpha=0.001000, l1_ratio=0.400000):
#   RMSE: 0.10486039725597326
#   Train R2: 0.9401376539049585
#   Test R2: 0.9354788843392237
# Elasticnet model (alpha=0.001274, l1_ratio=0.000000):
#   RMSE: 0.10559952687082926
#   Train R2: 0.9480530568396257
#   Test R2: 0.9345660985206443
# Elasticnet model (alpha=0.001274, l1_ratio=0.040000):
#   RMSE: 0.10434117720285234
#   Train R2: 0.9467046759797285
#   Test R2: 0.9361162597090886
# Elasticnet model (alpha=0.001274, l1_ratio=0.080000):
#   RMSE: 0.10401886178304577
#   Train R2: 0.9453133124416911
#   Test R2: 0.9365103306256368
# Elasticnet model (alpha=0.001274, l1_ratio=0.120000):
#   RMSE: 0.10398815535398093
#   Train R2: 0.9441861326498964
#   Test R2: 0.9365478094682766
# Elasticnet model (alpha=0.001274, l1_ratio=0.160000):
#   RMSE: 0.10429615444263363
#   Train R2: 0.9431999406577833
#   Test R2: 0.9361713789220287
# Elasticnet model (alpha=0.001274, l1_ratio=0.200000):
#   RMSE: 0.10452363068649427
#   Train R2: 0.9423855602130141
#   Test R2: 0.9358926470933961
# Elasticnet model (alpha=0.001274, l1_ratio=0.240000):
#   RMSE: 0.1045991719234303
#   Train R2: 0.9416135601478707
#   Test R2: 0.9357999503763526
# Elasticnet model (alpha=0.001274, l1_ratio=0.280000):
#   RMSE: 0.1047362145491939
#   Train R2: 0.940757883095239
#   Test R2: 0.9356316143036774
# Elasticnet model (alpha=0.001274, l1_ratio=0.320000):
#   RMSE: 0.10492072871685344
#   Train R2: 0.9399485798518229
#   Test R2: 0.9354046184945977
# Elasticnet model (alpha=0.001274, l1_ratio=0.360000):
#   RMSE: 0.10507008552615056
#   Train R2: 0.9393374859795903
#   Test R2: 0.9352205818969258
# Elasticnet model (alpha=0.001274, l1_ratio=0.400000):
#   RMSE: 0.10523118513506963
#   Train R2: 0.9387746820544793
#   Test R2: 0.9350217824124389
# Elasticnet model (alpha=0.001624, l1_ratio=0.000000):
#   RMSE: 0.10532104159308928
#   Train R2: 0.9475271335553025
#   Test R2: 0.9349107657912894
# Elasticnet model (alpha=0.001624, l1_ratio=0.040000):
#   RMSE: 0.10420227351921402
#   Train R2: 0.9458728489710505
#   Test R2: 0.9362862363292982
# Elasticnet model (alpha=0.001624, l1_ratio=0.080000):
#   RMSE: 0.10408242252461374
#   Train R2: 0.9443599973562681
#   Test R2: 0.9364327161751524
# Elasticnet model (alpha=0.001624, l1_ratio=0.120000):
#   RMSE: 0.1043701683298822
#   Train R2: 0.9431061684029536
#   Test R2: 0.936080754667328
# Elasticnet model (alpha=0.001624, l1_ratio=0.160000):
#   RMSE: 0.10455436511584053
#   Train R2: 0.9421528395633314
#   Test R2: 0.9358549409293008
# Elasticnet model (alpha=0.001624, l1_ratio=0.200000):
#   RMSE: 0.1046926323228933
#   Train R2: 0.9411592907235096
#   Test R2: 0.9356851723570758
# Elasticnet model (alpha=0.001624, l1_ratio=0.240000):
#   RMSE: 0.10489675078398455
#   Train R2: 0.9400944864179295
#   Test R2: 0.9354341395769703
# Elasticnet model (alpha=0.001624, l1_ratio=0.280000):
#   RMSE: 0.10510771034376525
#   Train R2: 0.9392889721806786
#   Test R2: 0.9351741795328068
# Elasticnet model (alpha=0.001624, l1_ratio=0.320000):
#   RMSE: 0.10533729455205988
#   Train R2: 0.9385609622840769
#   Test R2: 0.9348906753276347
# Elasticnet model (alpha=0.001624, l1_ratio=0.360000):
#   RMSE: 0.10567160556566417
#   Train R2: 0.9378137594220204
#   Test R2: 0.9344767420626889
# Elasticnet model (alpha=0.001624, l1_ratio=0.400000):
#   RMSE: 0.10597542907339336
#   Train R2: 0.9371904057813015
#   Test R2: 0.9340994197979354
# Elasticnet model (alpha=0.002069, l1_ratio=0.000000):
#   RMSE: 0.10510101334864792
#   Train R2: 0.9469633276553693
#   Test R2: 0.9351824400946828
# Elasticnet model (alpha=0.002069, l1_ratio=0.040000):
#   RMSE: 0.10421529812107432
#   Train R2: 0.944991837392663
#   Test R2: 0.9362703077273687
# Elasticnet model (alpha=0.002069, l1_ratio=0.080000):
#   RMSE: 0.10432050018862875
#   Train R2: 0.9433409972038114
#   Test R2: 0.9361415765429592
# Elasticnet model (alpha=0.002069, l1_ratio=0.120000):
#   RMSE: 0.10457981558160041
#   Train R2: 0.9421137564599874
#   Test R2: 0.935823708941603
# Elasticnet model (alpha=0.002069, l1_ratio=0.160000):
#   RMSE: 0.10476886375186628
#   Train R2: 0.9408835472374307
#   Test R2: 0.9355914772023056
# Elasticnet model (alpha=0.002069, l1_ratio=0.200000):
#   RMSE: 0.1050464267344603
#   Train R2: 0.9396394754455574
#   Test R2: 0.9352497515735619
# Elasticnet model (alpha=0.002069, l1_ratio=0.240000):
#   RMSE: 0.10537688128702365
#   Train R2: 0.938650068231235
#   Test R2: 0.9348417287525741
# Elasticnet model (alpha=0.002069, l1_ratio=0.280000):
#   RMSE: 0.10575347557099878
#   Train R2: 0.9377470941399684
#   Test R2: 0.9343751732921173
# Elasticnet model (alpha=0.002069, l1_ratio=0.320000):
#   RMSE: 0.1061444038398873
#   Train R2: 0.9369647588860155
#   Test R2: 0.9338890991057941
# Elasticnet model (alpha=0.002069, l1_ratio=0.360000):
#   RMSE: 0.10656163768066082
#   Train R2: 0.9363020160171786
#   Test R2: 0.9333683383818082
# Elasticnet model (alpha=0.002069, l1_ratio=0.400000):
#   RMSE: 0.10696875960795188
#   Train R2: 0.9356644020711936
#   Test R2: 0.9328582292797314
# Elasticnet model (alpha=0.002637, l1_ratio=0.000000):
#   RMSE: 0.10493786434367175
#   Train R2: 0.9463641086132086
#   Test R2: 0.935383517368956
# Elasticnet model (alpha=0.002637, l1_ratio=0.040000):
#   RMSE: 0.10431376427307745
#   Train R2: 0.9441147017698076
#   Test R2: 0.9361498228811144
# Elasticnet model (alpha=0.002637, l1_ratio=0.080000):
#   RMSE: 0.10456265029328331
#   Train R2: 0.9423764266131865
#   Test R2: 0.9358447744622613
# Elasticnet model (alpha=0.002637, l1_ratio=0.120000):
#   RMSE: 0.10480145441644613
#   Train R2: 0.940897851047019
#   Test R2: 0.9355513995881054
# Elasticnet model (alpha=0.002637, l1_ratio=0.160000):
#   RMSE: 0.1051538807173645
#   Train R2: 0.9393858262087295
#   Test R2: 0.9351172153060991
# Elasticnet model (alpha=0.002637, l1_ratio=0.200000):
#   RMSE: 0.10569367946879246
#   Train R2: 0.9381120920805813
#   Test R2: 0.934449364696628
# Elasticnet model (alpha=0.002637, l1_ratio=0.240000):
#   RMSE: 0.10612505759130973
#   Train R2: 0.9370732432143285
#   Test R2: 0.9339131961155056
# Elasticnet model (alpha=0.002637, l1_ratio=0.280000):
#   RMSE: 0.10665928455762834
#   Train R2: 0.9362074447096005
#   Test R2: 0.9332461676862981
# Elasticnet model (alpha=0.002637, l1_ratio=0.320000):
#   RMSE: 0.10718121516459557
#   Train R2: 0.935388816189904
#   Test R2: 0.9325912577236493
# Elasticnet model (alpha=0.002637, l1_ratio=0.360000):
#   RMSE: 0.10775114343405372
#   Train R2: 0.9345158168828572
#   Test R2: 0.9318724696297127
# Elasticnet model (alpha=0.002637, l1_ratio=0.400000):
#   RMSE: 0.10833350952220198
#   Train R2: 0.9336050475883992
#   Test R2: 0.9311340574160127
# Elasticnet model (alpha=0.003360, l1_ratio=0.000000):
#   RMSE: 0.10483060162070512
#   Train R2: 0.9457308198512284
#   Test R2: 0.9355155459302908
# Elasticnet model (alpha=0.003360, l1_ratio=0.040000):
#   RMSE: 0.10448400822978171
#   Train R2: 0.9431394401678083
#   Test R2: 0.9359412410688329
# Elasticnet model (alpha=0.003360, l1_ratio=0.080000):
#   RMSE: 0.10478901245757485
#   Train R2: 0.9412955715857528
#   Test R2: 0.9355667012695859
# Elasticnet model (alpha=0.003360, l1_ratio=0.120000):
#   RMSE: 0.10525080863766632
#   Train R2: 0.9393698148385765
#   Test R2: 0.9349975458876822
# Elasticnet model (alpha=0.003360, l1_ratio=0.160000):
#   RMSE: 0.10588817213012357
#   Train R2: 0.9378158479276683
#   Test R2: 0.9342078961859869
# Elasticnet model (alpha=0.003360, l1_ratio=0.200000):
#   RMSE: 0.10648403866607896
#   Train R2: 0.9365512454296118
#   Test R2: 0.9334653464379185
# Elasticnet model (alpha=0.003360, l1_ratio=0.240000):
#   RMSE: 0.10715471060649606
#   Train R2: 0.9354946023813584
#   Test R2: 0.932624592259309
# Elasticnet model (alpha=0.003360, l1_ratio=0.280000):
#   RMSE: 0.1078566088040081
#   Train R2: 0.9344091485403467
#   Test R2: 0.9317390397411242
# Elasticnet model (alpha=0.003360, l1_ratio=0.320000):
#   RMSE: 0.10858407361227386
#   Train R2: 0.9332523292251769
#   Test R2: 0.9308151295569023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-63e36c4f7c9c> in <module>
# ----> 1 train_elasticnet(20, 11)
#
# <ipython-input-1-10ea4ee1d91c> in train_elasticnet(N_alpha, N_rho)
#     155                 mlflow.log_metric("rmse", rmse)
#     156                 mlflow.log_metric("r2_test", r2_test)
# --> 157                 mlflow.log_metric("r2_train", r2_train)
#     158                 #mlflow.log_metric("mae", mae)
#     159
#
# ~\Anaconda3\lib\site-packages\mlflow\tracking\fluent.py in log_metric(key, value, step)
#     235     """
#     236     run_id = _get_or_start_run().info.run_id
# --> 237     MlflowClient().log_metric(run_id, key, value, int(time.time() * 1000), step or 0)
#     238
#     239
#
# ~\Anaconda3\lib\site-packages\mlflow\tracking\client.py in log_metric(self, run_id, key, value, timestamp, step)
#     193         :param step: Training step (iteration) at which was the metric calculated. Defaults to 0.
#     194         """
# --> 195         self._tracking_client.log_metric(run_id, key, value, timestamp, step)
#     196
#     197     def log_param(self, run_id, key, value):
#
# ~\Anaconda3\lib\site-packages\mlflow\tracking\_tracking_service\client.py in log_metric(self, run_id, key, value, timestamp, step)
#     167         _validate_metric(key, value, timestamp, step)
#     168         metric = Metric(key, value, timestamp, step)
# --> 169         self.store.log_metric(run_id, metric)
#     170
#     171     def log_param(self, run_id, key, value):
#
# ~\Anaconda3\lib\site-packages\mlflow\store\tracking\file_store.py in log_metric(self, run_id, metric)
#     595         _validate_run_id(run_id)
#     596         _validate_metric_name(metric.key)
# --> 597         run = self.get_run(run_id)
#     598         check_run_is_active(run.info)
#     599         metric_path = self._get_metric_path(run.info.experiment_id, run_id, metric.key)
#
# ~\Anaconda3\lib\site-packages\mlflow\store\tracking\file_store.py in get_run(self, run_id)
#     399         metrics = self.get_all_metrics(run_id)
#     400         params = self.get_all_params(run_id)
# --> 401         tags = self.get_all_tags(run_id)
#     402         return Run(run_info, RunData(metrics, params, tags))
#     403
#
# ~\Anaconda3\lib\site-packages\mlflow\store\tracking\file_store.py in get_all_tags(self, run_uuid)
#     544
#     545     def get_all_tags(self, run_uuid):
# --> 546         parent_path, tag_files = self._get_run_files(run_uuid, "tag")
#     547         tags = []
#     548         for tag_file in tag_files:
#
# ~\Anaconda3\lib\site-packages\mlflow\store\tracking\file_store.py in _get_run_files(self, run_uuid, resource_type)
#     422     def _get_run_files(self, run_uuid, resource_type):
#     423         _validate_run_id(run_uuid)
# --> 424         run_info = self._get_run_info(run_uuid)
#     425         if run_info is None:
#     426             raise MlflowException("Run '%s' metadata is in invalid state." % run_uuid,
#
# ~\Anaconda3\lib\site-packages\mlflow\store\tracking\file_store.py in _get_run_info(self, run_uuid)
#     411                                   databricks_pb2.RESOURCE_DOES_NOT_EXIST)
#     412
# --> 413         meta = read_yaml(run_dir, FileStore.META_DATA_FILE_NAME)
#     414         run_info = _read_persisted_run_info_dict(meta)
#     415         if run_info.experiment_id != exp_id:
#
# ~\Anaconda3\lib\site-packages\mlflow\utils\file_utils.py in read_yaml(root, file_name)
#     160     try:
#     161         with codecs.open(file_path, mode='r', encoding=ENCODING) as yaml_file:
# --> 162             return yaml.safe_load(yaml_file)
#     163     except Exception as e:
#     164         raise e
#
# ~\Anaconda3\lib\codecs.py in __exit__(self, type, value, tb)
#     749
#     750     def __exit__(self, type, value, tb):
# --> 751         self.stream.close()
#     752
#     753 ###
#
# KeyboardInterrupt:
