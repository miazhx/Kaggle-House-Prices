# %%
# MLflow Training
def train(N_alpha, N_rho):
    import os
    import warnings
    import sys

    import pandas as pd
    import numpy as np
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import ElasticNet

    import mlflow
    import mlflow.sklearn
    
    import logging
    logging.basicConfig(level=logging.WARN)
    logger = logging.getLogger(__name__)
    
    from data_processing import data_process

    def eval_metrics(actual, pred):
        rmse = np.sqrt(mean_squared_error(actual, pred))
        mae = mean_absolute_error(actual, pred)
        r2 = r2_score(actual, pred)
        return rmse, mae, r2


    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the file
    try:
        df_raw = pd.read_csv('train.csv',index_col=0)
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e)
        
    # Data processing.
    df_processed = data_process(df_raw)
    
    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(df_processed)

    # The predicted column is "SalePrice" .
    train_x = train.drop(["SalePrice"], axis=1)
    test_x = test.drop(["SalePrice"], axis=1)
    train_y = train[["SalePrice"]]
    test_y = test[["SalePrice"]]

    # Set default values if no N_alpha is provided
    if int(N_alpha) is None:
        N_alpha = 50
    else:
        N_alpha = int(N_alpha)

    # Set default values if no N_rho is provided
    if int(N_rho) is None:
        N_rho = 11
    else:
        N_rho = int(N_rho)
    
    alphaRange = np.logspace(-3, -2, N_alpha)
    rhoRange   = np.linspace(0,1, N_rho) # we avoid very small rho by starting at 0.1
    scores     = np.zeros((N_rho, N_alpha))
    
    # Useful for multiple runs (only doing one run in this sample notebook)    
    
        # Execute ElasticNet
    for alphaIdx, alpha in enumerate(alphaRange):
        for rhoIdx, rho in enumerate(rhoRange):
            with mlflow.start_run():
                lr = ElasticNet(alpha=alpha, l1_ratio=rho, normalize=False)
                lr.fit(train_x, train_y)
                scores[rhoIdx, alphaIdx] = lr.score(train_x, train_y)
        
        # Training Model Performances Evaluate Metrics
#         predicted_qualities = lr.predict(test_x)
#         (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)        

        # Evaluate Metrics
                predicted_qualities = lr.predict(test_x)
                (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        # Print out metrics
                print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, rho))
                print("  RMSE: %s" % rmse)
                #print("  MAE: %s" % mae)
                print("  R2: %s" % r2)

        # Log parameter, metrics, and model to MLflow
                mlflow.log_param("alpha", alpha)
                mlflow.log_param("l1_ratio", rho)
                mlflow.log_metric("rmse", rmse)
                mlflow.log_metric("r2", r2)
                #mlflow.log_metric("mae", mae)

                mlflow.sklearn.log_model(lr, "model")

# %%
train(50,11)
# Out:
# Elasticnet model (alpha=0.001000, l1_ratio=0.000000):
#   RMSE: 0.12113252803450762
#   R2: 0.9000325455793695
# Elasticnet model (alpha=0.001000, l1_ratio=0.100000):
#   RMSE: 0.11894880469661961
#   R2: 0.9036043944909556
# Elasticnet model (alpha=0.001000, l1_ratio=0.200000):
#   RMSE: 0.11806401547824101
#   R2: 0.9050331197769326
# Elasticnet model (alpha=0.001000, l1_ratio=0.300000):
#   RMSE: 0.11745241007083222
#   R2: 0.9060144825718847
# Elasticnet model (alpha=0.001000, l1_ratio=0.400000):
#   RMSE: 0.11756965994879676
#   R2: 0.9058267420080882
# Elasticnet model (alpha=0.001000, l1_ratio=0.500000):
#   RMSE: 0.1177547050543906
#   R2: 0.9055300665857328
# Elasticnet model (alpha=0.001000, l1_ratio=0.600000):
#   RMSE: 0.11799975938628075
#   R2: 0.9051364626966049
# Elasticnet model (alpha=0.001000, l1_ratio=0.700000):
#   RMSE: 0.1183980305304694
#   R2: 0.9044950178430892
# Elasticnet model (alpha=0.001000, l1_ratio=0.800000):
#   RMSE: 0.11877826748513717
#   R2: 0.9038806016114713
# Elasticnet model (alpha=0.001000, l1_ratio=0.900000):
#   RMSE: 0.11927919867650505
#   R2: 0.9030681510322245
# Elasticnet model (alpha=0.001000, l1_ratio=1.000000):
#   RMSE: 0.11989155105226892
#   R2: 0.9020703440392291
# Elasticnet model (alpha=0.001048, l1_ratio=0.000000):
#   RMSE: 0.12105266651907705
#   R2: 0.9001643172973953
# Elasticnet model (alpha=0.001048, l1_ratio=0.100000):
#   RMSE: 0.11888317009385561
#   R2: 0.9037107451472662
# Elasticnet model (alpha=0.001048, l1_ratio=0.200000):
#   RMSE: 0.11799754933559567
#   R2: 0.9051400161150758
# Elasticnet model (alpha=0.001048, l1_ratio=0.300000):
#   RMSE: 0.1174953392297588
#   R2: 0.9059457661179239
# Elasticnet model (alpha=0.001048, l1_ratio=0.400000):
#   RMSE: 0.11756203775676902
#   R2: 0.9058389523587593
# Elasticnet model (alpha=0.001048, l1_ratio=0.500000):
#   RMSE: 0.1178093637488401
#   R2: 0.9054423452224389
# Elasticnet model (alpha=0.001048, l1_ratio=0.600000):
#   RMSE: 0.11814529148231881
#   R2: 0.9049023231873948
# Elasticnet model (alpha=0.001048, l1_ratio=0.700000):
#   RMSE: 0.11856225118749211
#   R2: 0.9042298991109913
# Elasticnet model (alpha=0.001048, l1_ratio=0.800000):
#   RMSE: 0.11898502869394101
#   R2: 0.903545674004333
# Elasticnet model (alpha=0.001048, l1_ratio=0.900000):
#   RMSE: 0.119560125724051
#   R2: 0.9026110244671902
# Elasticnet model (alpha=0.001048, l1_ratio=1.000000):
#   RMSE: 0.12027038135051873
#   R2: 0.901450494979809
# Elasticnet model (alpha=0.001099, l1_ratio=0.000000):
#   RMSE: 0.12097465231448985
#   R2: 0.900292957035105
# Elasticnet model (alpha=0.001099, l1_ratio=0.100000):
#   RMSE: 0.11882065444900229
#   R2: 0.9038119874363459
# Elasticnet model (alpha=0.001099, l1_ratio=0.200000):
#   RMSE: 0.1179274054932582
#   R2: 0.9052527619491526
# Elasticnet model (alpha=0.001099, l1_ratio=0.300000):
#   RMSE: 0.11755528282941362
#   R2: 0.9058497727353949
# Elasticnet model (alpha=0.001099, l1_ratio=0.400000):
#   RMSE: 0.11759092201772768
#   R2: 0.9057926771080121
# Elasticnet model (alpha=0.001099, l1_ratio=0.500000):
#   RMSE: 0.11787546548694428
#   R2: 0.9053362046125476
# Elasticnet model (alpha=0.001099, l1_ratio=0.600000):
#   RMSE: 0.11829065750327657
#   R2: 0.9046681627698769
# Elasticnet model (alpha=0.001099, l1_ratio=0.700000):
#   RMSE: 0.11871145148755649
#   R2: 0.9039887107338445
# Elasticnet model (alpha=0.001099, l1_ratio=0.800000):
#   RMSE: 0.11921659835169666
#   R2: 0.9031698682301387
# Elasticnet model (alpha=0.001099, l1_ratio=0.900000):
#   RMSE: 0.11987703641119175
#   R2: 0.9020940542632283
# Elasticnet model (alpha=0.001099, l1_ratio=1.000000):
#   RMSE: 0.12069590405868937
#   R2: 0.9007519150640546
# Elasticnet model (alpha=0.001151, l1_ratio=0.000000):
#   RMSE: 0.12089842754661825
#   R2: 0.9004185660230456
# Elasticnet model (alpha=0.001151, l1_ratio=0.100000):
#   RMSE: 0.11876863164930632
#   R2: 0.903896196268545
# Elasticnet model (alpha=0.001151, l1_ratio=0.200000):
#   RMSE: 0.11787334063504977
#   R2: 0.9053396174471214
# Elasticnet model (alpha=0.001151, l1_ratio=0.300000):
#   RMSE: 0.11764608042070782
#   R2: 0.9057042766751996
# Elasticnet model (alpha=0.001151, l1_ratio=0.400000):
#   RMSE: 0.11766954428660034
#   R2: 0.9056666593939757
# Elasticnet model (alpha=0.001151, l1_ratio=0.500000):
#   RMSE: 0.11795996465649412
#   R2: 0.90520043625542
# Elasticnet model (alpha=0.001151, l1_ratio=0.600000):
#   RMSE: 0.11844178369518779
#   R2: 0.904424418403359
# Elasticnet model (alpha=0.001151, l1_ratio=0.700000):
#   RMSE: 0.11889800946869765
#   R2: 0.9036867053858251
# Elasticnet model (alpha=0.001151, l1_ratio=0.800000):
#   RMSE: 0.11949945075530186
#   R2: 0.9027098462713371
# Elasticnet model (alpha=0.001151, l1_ratio=0.900000):
#   RMSE: 0.12024895028646655
#   R2: 0.9014856130622404
# Elasticnet model (alpha=0.001151, l1_ratio=1.000000):
#   RMSE: 0.12118720552917607
#   R2: 0.8999422774461896
# Elasticnet model (alpha=0.001207, l1_ratio=0.000000):
#   RMSE: 0.12082393374412527
#   R2: 0.9005412461007714
# Elasticnet model (alpha=0.001207, l1_ratio=0.100000):
#   RMSE: 0.11872028168972468
#   R2: 0.9039744268443753
# Elasticnet model (alpha=0.001207, l1_ratio=0.200000):
#   RMSE: 0.11782605861360892
#   R2: 0.9054155436327617
# Elasticnet model (alpha=0.001207, l1_ratio=0.300000):
#   RMSE: 0.11772112825085376
#   R2: 0.9055839335825218
# Elasticnet model (alpha=0.001207, l1_ratio=0.400000):
#   RMSE: 0.11776889313337721
#   R2: 0.905507300147234
# Elasticnet model (alpha=0.001207, l1_ratio=0.500000):
#   RMSE: 0.11810267467124176
#   R2: 0.9049709171826288
# Elasticnet model (alpha=0.001207, l1_ratio=0.600000):
#   RMSE: 0.11861015102981398
#   R2: 0.9041525001185047
# Elasticnet model (alpha=0.001207, l1_ratio=0.700000):
#   RMSE: 0.11910900187745414
#   R2: 0.9033445734202817
# Elasticnet model (alpha=0.001207, l1_ratio=0.800000):
#   RMSE: 0.11978934426040247
#   R2: 0.9022372416986459
# Elasticnet model (alpha=0.001207, l1_ratio=0.900000):
#   RMSE: 0.12066630952474469
#   R2: 0.9008005801905459
# Elasticnet model (alpha=0.001207, l1_ratio=1.000000):
#   RMSE: 0.12175450996356432
#   R2: 0.8990032996052655
# Elasticnet model (alpha=0.001265, l1_ratio=0.000000):
#   RMSE: 0.12075111244522309
#   R2: 0.9006610987294352
# Elasticnet model (alpha=0.001265, l1_ratio=0.100000):
#   RMSE: 0.11868061856117205
#   R2: 0.9040385782830385
# Elasticnet model (alpha=0.001265, l1_ratio=0.200000):
#   RMSE: 0.1177740161162932
#   R2: 0.905499079045667
# Elasticnet model (alpha=0.001265, l1_ratio=0.300000):
#   RMSE: 0.11765695693994795
#   R2: 0.9056868403669991
# Elasticnet model (alpha=0.001265, l1_ratio=0.400000):
#   RMSE: 0.1178606457465227
#   R2: 0.9053600060826962
# Elasticnet model (alpha=0.001265, l1_ratio=0.500000):
#   RMSE: 0.11825868978397876
#   R2: 0.9047196821321369
# Elasticnet model (alpha=0.001265, l1_ratio=0.600000):
#   RMSE: 0.11877306693787802
#   R2: 0.9038890183452944
# Elasticnet model (alpha=0.001265, l1_ratio=0.700000):
#   RMSE: 0.1193532212819019
#   R2: 0.9029478052473353
# Elasticnet model (alpha=0.001265, l1_ratio=0.800000):
#   RMSE: 0.12014440465038315
#   R2: 0.9016568373779
# Elasticnet model (alpha=0.001265, l1_ratio=0.900000):
#   RMSE: 0.12115176383902368
#   R2: 0.9000007934624995
# Elasticnet model (alpha=0.001265, l1_ratio=1.000000):
#   RMSE: 0.1223558526927196
#   R2: 0.898003195174228
# Elasticnet model (alpha=0.001326, l1_ratio=0.000000):
#   RMSE: 0.1206799058166931
#   R2: 0.9007782239874891
# Elasticnet model (alpha=0.001326, l1_ratio=0.100000):
#   RMSE: 0.11863951838751138
#   R2: 0.9041050313942245
# Elasticnet model (alpha=0.001326, l1_ratio=0.200000):
#   RMSE: 0.11772360516047833
#   R2: 0.9055799604210788
# Elasticnet model (alpha=0.001326, l1_ratio=0.300000):
#   RMSE: 0.11762948552696123
#   R2: 0.9057308770878645
# Elasticnet model (alpha=0.001326, l1_ratio=0.400000):
#   RMSE: 0.11793117268098369
#   R2: 0.9052467084566368
# Elasticnet model (alpha=0.001326, l1_ratio=0.500000):
#   RMSE: 0.11842177282925391
#   R2: 0.9044567108685098
# Elasticnet model (alpha=0.001326, l1_ratio=0.600000):
#   RMSE: 0.11895678261012148
#   R2: 0.9035914635229758
# Elasticnet model (alpha=0.001326, l1_ratio=0.700000):
#   RMSE: 0.11964531144563047
#   R2: 0.9024721971520169
# Elasticnet model (alpha=0.001326, l1_ratio=0.800000):
#   RMSE: 0.1205425694638161
#   R2: 0.9010039285565936
# Elasticnet model (alpha=0.001326, l1_ratio=0.900000):
#   RMSE: 0.12170731206990461
#   R2: 0.8990815867685132
# Elasticnet model (alpha=0.001326, l1_ratio=1.000000):
#   RMSE: 0.12302490711791608
#   R2: 0.8968846873519452
# Elasticnet model (alpha=0.001389, l1_ratio=0.000000):
#   RMSE: 0.12061025730740933
#   R2: 0.9008927195127364
# Elasticnet model (alpha=0.001389, l1_ratio=0.100000):
#   RMSE: 0.11859878142112426
#   R2: 0.9041708745380309
# Elasticnet model (alpha=0.001389, l1_ratio=0.200000):
#   RMSE: 0.11768270035705246
#   R2: 0.9056455642931015
# Elasticnet model (alpha=0.001389, l1_ratio=0.300000):
#   RMSE: 0.11763451531256422
#   R2: 0.9057228151021743
# Elasticnet model (alpha=0.001389, l1_ratio=0.400000):
#   RMSE: 0.1180134218872875
#   R2: 0.9051144940381429
# Elasticnet model (alpha=0.001389, l1_ratio=0.500000):
#   RMSE: 0.11858555547068825
#   R2: 0.9041922467743646
# Elasticnet model (alpha=0.001389, l1_ratio=0.600000):
#   RMSE: 0.11916760912523769
#   R2: 0.9032494319599759
# Elasticnet model (alpha=0.001389, l1_ratio=0.700000):
#   RMSE: 0.11995073911402553
#   R2: 0.9019736283453479
# Elasticnet model (alpha=0.001389, l1_ratio=0.800000):
#   RMSE: 0.12100093902413891
#   R2: 0.9002496214305811
# Elasticnet model (alpha=0.001389, l1_ratio=0.900000):
#   RMSE: 0.12230468309471258
#   R2: 0.8980884880973985
# Elasticnet model (alpha=0.001389, l1_ratio=1.000000):
#   RMSE: 0.12377076279504916
#   R2: 0.8956305953253935
# Elasticnet model (alpha=0.001456, l1_ratio=0.000000):
#   RMSE: 0.12054211234657737
#   R2: 0.9010046793739227
# Elasticnet model (alpha=0.001456, l1_ratio=0.100000):
#   RMSE: 0.11855093351354103
#   R2: 0.9042481822159804
# Elasticnet model (alpha=0.001456, l1_ratio=0.200000):
#   RMSE: 0.11769915772062542
#   R2: 0.9056191724134788
# Elasticnet model (alpha=0.001456, l1_ratio=0.300000):
#   RMSE: 0.11767730519063645
#   R2: 0.9056542154578402
# Elasticnet model (alpha=0.001456, l1_ratio=0.400000):
#   RMSE: 0.11811284775435607
#   R2: 0.904954545319811
# Elasticnet model (alpha=0.001456, l1_ratio=0.500000):
#   RMSE: 0.1187527561968802
#   R2: 0.903921886375025
# Elasticnet model (alpha=0.001456, l1_ratio=0.600000):
#   RMSE: 0.11939932741697518
#   R2: 0.9028728082620725
# Elasticnet model (alpha=0.001456, l1_ratio=0.700000):
#   RMSE: 0.1203178769577029
#   R2: 0.9013726438457177
# Elasticnet model (alpha=0.001456, l1_ratio=0.800000):
#   RMSE: 0.12153375141769561
#   R2: 0.8993692108456888
# Elasticnet model (alpha=0.001456, l1_ratio=0.900000):
#   RMSE: 0.12295741261553733
#   R2: 0.896997799529659
# Elasticnet model (alpha=0.001456, l1_ratio=1.000000):
#   RMSE: 0.12453982877721094
#   R2: 0.8943295395417781
# Elasticnet model (alpha=0.001526, l1_ratio=0.000000):
#   RMSE: 0.12047541908715949
#   R2: 0.9011141928711212
# Elasticnet model (alpha=0.001526, l1_ratio=0.100000):
#   RMSE: 0.11849848128065618
#   R2: 0.9043328932415342
# Elasticnet model (alpha=0.001526, l1_ratio=0.200000):
#   RMSE: 0.11773656956005624
#   R2: 0.9055591631218115
# Elasticnet model (alpha=0.001526, l1_ratio=0.300000):
#   RMSE: 0.1177625430907192
#   R2: 0.9055174898753062
# Elasticnet model (alpha=0.001526, l1_ratio=0.400000):
#   RMSE: 0.1182746952975749
#   R2: 0.9046938892939821
# Elasticnet model (alpha=0.001526, l1_ratio=0.500000):
#   RMSE: 0.11893205011652147
#   R2: 0.9036315482593726
# Elasticnet model (alpha=0.001526, l1_ratio=0.600000):
#   RMSE: 0.11969073604772458
#   R2: 0.9023981281799411
# Elasticnet model (alpha=0.001526, l1_ratio=0.700000):
#   RMSE: 0.12072855895343484
#   R2: 0.900698203644128
# Elasticnet model (alpha=0.001526, l1_ratio=0.800000):
#   RMSE: 0.12211772517649394
#   R2: 0.8983998188013531
# Elasticnet model (alpha=0.001526, l1_ratio=0.900000):
#   RMSE: 0.12368291096010602
#   R2: 0.8957787044496512
# Elasticnet model (alpha=0.001526, l1_ratio=1.000000):
#   RMSE: 0.12537564559788938
#   R2: 0.8929064201841994
# Elasticnet model (alpha=0.001600, l1_ratio=0.000000):
#   RMSE: 0.12041012918828693
#   R2: 0.9012213432751203
# Elasticnet model (alpha=0.001600, l1_ratio=0.100000):
#   RMSE: 0.11844564195910923
#   R2: 0.9044181915159737
# Elasticnet model (alpha=0.001600, l1_ratio=0.200000):
#   RMSE: 0.11778313153919906
#   R2: 0.9054844501958808
# Elasticnet model (alpha=0.001600, l1_ratio=0.300000):
#   RMSE: 0.11787691054092811
#   R2: 0.9053338836014266
# Elasticnet model (alpha=0.001600, l1_ratio=0.400000):
#   RMSE: 0.11844429699031568
#   R2: 0.9044203621964249
# Elasticnet model (alpha=0.001600, l1_ratio=0.500000):
#   RMSE: 0.11913996528799481
#   R2: 0.9032943140678118
# Elasticnet model (alpha=0.001600, l1_ratio=0.600000):
#   RMSE: 0.1199943341059944
#   R2: 0.901902361832257
# Elasticnet model (alpha=0.001600, l1_ratio=0.700000):
#   RMSE: 0.12122154245182579
#   R2: 0.8998855691329131
# Elasticnet model (alpha=0.001600, l1_ratio=0.800000):
#   RMSE: 0.12274559725560846
#   R2: 0.8973523719875991
# Elasticnet model (alpha=0.001600, l1_ratio=0.900000):
#   RMSE: 0.12444664796394077
#   R2: 0.894487605856399
# Elasticnet model (alpha=0.001600, l1_ratio=1.000000):
#   RMSE: 0.12625962788073988
#   R2: 0.8913909334079071
# Elasticnet model (alpha=0.001677, l1_ratio=0.000000):
#   RMSE: 0.12034619862674376
#   R2: 0.9013262065220722
# Elasticnet model (alpha=0.001677, l1_ratio=0.100000):
#   RMSE: 0.11839612024978241
#   R2: 0.9044980996485942
# Elasticnet model (alpha=0.001677, l1_ratio=0.200000):
#   RMSE: 0.11783662487321593
#   R2: 0.9053985788162485
# Elasticnet model (alpha=0.001677, l1_ratio=0.300000):
#   RMSE: 0.11799331878770745
#   R2: 0.9051468179938048
# Elasticnet model (alpha=0.001677, l1_ratio=0.400000):
#   RMSE: 0.11862430423013497
#   R2: 0.9041296246767375
# Elasticnet model (alpha=0.001677, l1_ratio=0.500000):
#   RMSE: 0.1193518566558104
#   R2: 0.9029500245288704
# Elasticnet model (alpha=0.001677, l1_ratio=0.600000):
#   RMSE: 0.12035650566221934
#   R2: 0.9013093039883258
# Elasticnet model (alpha=0.001677, l1_ratio=0.700000):
#   RMSE: 0.12176578593805355
#   R2: 0.8989845916501736
# Elasticnet model (alpha=0.001677, l1_ratio=0.800000):
#   RMSE: 0.12342665004187281
#   R2: 0.8962101331159135
# Elasticnet model (alpha=0.001677, l1_ratio=0.900000):
#   RMSE: 0.1252611487303735
#   R2: 0.8931019331229395
# Elasticnet model (alpha=0.001677, l1_ratio=1.000000):
#   RMSE: 0.12704324338769424
#   R2: 0.8900386111205874
# Elasticnet model (alpha=0.001758, l1_ratio=0.000000):
#   RMSE: 0.12028358852620141
#   R2: 0.9014288498818994
# Elasticnet model (alpha=0.001758, l1_ratio=0.100000):
#   RMSE: 0.1183508007815662
#   R2: 0.9045711977700174
# Elasticnet model (alpha=0.001758, l1_ratio=0.200000):
#   RMSE: 0.11780045745460405
#   R2: 0.9054566416490671
# Elasticnet model (alpha=0.001758, l1_ratio=0.300000):
#   RMSE: 0.11809555025398008
#   R2: 0.904982381891949
# Elasticnet model (alpha=0.001758, l1_ratio=0.400000):
#   RMSE: 0.11880542437237385
#   R2: 0.903836644040408
# Elasticnet model (alpha=0.001758, l1_ratio=0.500000):
#   RMSE: 0.11959914131030862
#   R2: 0.9025474529725794
# Elasticnet model (alpha=0.001758, l1_ratio=0.600000):
#   RMSE: 0.1207667092049724
#   R2: 0.9006354349486717
# Elasticnet model (alpha=0.001758, l1_ratio=0.700000):
#   RMSE: 0.12236075040918602
#   R2: 0.8979950294605714
# Elasticnet model (alpha=0.001758, l1_ratio=0.800000):
#   RMSE: 0.12418165157502327
#   R2: 0.8949364830979093
# Elasticnet model (alpha=0.001758, l1_ratio=0.900000):
#   RMSE: 0.12614077753989603
#   R2: 0.8915953083048367
# Elasticnet model (alpha=0.001758, l1_ratio=1.000000):
#   RMSE: 0.1278232629111816
#   R2: 0.8886841850335268
# Elasticnet model (alpha=0.001842, l1_ratio=0.000000):
#   RMSE: 0.12022226599290342
#   R2: 0.9015293306188525
# Elasticnet model (alpha=0.001842, l1_ratio=0.100000):
#   RMSE: 0.11830905210211713
#   R2: 0.9046385116159436
# Elasticnet model (alpha=0.001842, l1_ratio=0.200000):
#   RMSE: 0.11774936909679594
#   R2: 0.9055386280463943
# Elasticnet model (alpha=0.001842, l1_ratio=0.300000):
#   RMSE: 0.11819909990355366
#   R2: 0.9048156803588695
# Elasticnet model (alpha=0.001842, l1_ratio=0.400000):
#   RMSE: 0.11898556578401465
#   R2: 0.9035448032262436
# Elasticnet model (alpha=0.001842, l1_ratio=0.500000):
#   RMSE: 0.11990551210765477
#   R2: 0.902047535410226
# Elasticnet model (alpha=0.001842, l1_ratio=0.600000):
#   RMSE: 0.12125468580905042
#   R2: 0.899830816786332
# Elasticnet model (alpha=0.001842, l1_ratio=0.700000):
#   RMSE: 0.12300193507899829
#   R2: 0.8969231925274322
# Elasticnet model (alpha=0.001842, l1_ratio=0.800000):
#   RMSE: 0.12495721220995058
#   R2: 0.8936200635935697
# Elasticnet model (alpha=0.001842, l1_ratio=0.900000):
#   RMSE: 0.12694454143294012
#   R2: 0.8902094063183142
# Elasticnet model (alpha=0.001842, l1_ratio=1.000000):
#   RMSE: 0.12866451471837828
#   R2: 0.8872141429893501
# Elasticnet model (alpha=0.001931, l1_ratio=0.000000):
#   RMSE: 0.12016220494721797
#   R2: 0.901627694661365
# Elasticnet model (alpha=0.001931, l1_ratio=0.100000):
#   RMSE: 0.11827967653636036
#   R2: 0.9046858613300793
# Elasticnet model (alpha=0.001931, l1_ratio=0.200000):
#   RMSE: 0.11773700125837963
#   R2: 0.9055584705583057
# Elasticnet model (alpha=0.001931, l1_ratio=0.300000):
#   RMSE: 0.11831916471568979
#   R2: 0.9046222086352455
# Elasticnet model (alpha=0.001931, l1_ratio=0.400000):
#   RMSE: 0.11919114124662042
#   R2: 0.9032112173658743
# Elasticnet model (alpha=0.001931, l1_ratio=0.500000):
#   RMSE: 0.12022553615456733
#   R2: 0.9015239735515085
# Elasticnet model (alpha=0.001931, l1_ratio=0.600000):
#   RMSE: 0.12179227083616449
#   R2: 0.8989406437754194
# Elasticnet model (alpha=0.001931, l1_ratio=0.700000):
#   RMSE: 0.12369479801926613
#   R2: 0.8957586702471828
# Elasticnet model (alpha=0.001931, l1_ratio=0.800000):
#   RMSE: 0.12580402182836667
#   R2: 0.8921733477022875
# Elasticnet model (alpha=0.001931, l1_ratio=0.900000):
#   RMSE: 0.12772917258921485
#   R2: 0.8888480031959965
# Elasticnet model (alpha=0.001931, l1_ratio=1.000000):
#   RMSE: 0.1296106524902483
#   R2: 0.8855492968496328
# Elasticnet model (alpha=0.002024, l1_ratio=0.000000):
#   RMSE: 0.12010338694140309
#   R2: 0.901723975296772
# Elasticnet model (alpha=0.002024, l1_ratio=0.100000):
#   RMSE: 0.11826436190419813
#   R2: 0.9047105419263854
# Elasticnet model (alpha=0.002024, l1_ratio=0.200000):
#   RMSE: 0.11775417214009339
#   R2: 0.905530921655842
# Elasticnet model (alpha=0.002024, l1_ratio=0.300000):
#   RMSE: 0.11847802246513432
#   R2: 0.9043659243269748
# Elasticnet model (alpha=0.002024, l1_ratio=0.400000):
#   RMSE: 0.11941427732568471
#   R2: 0.9028484842799238
# Elasticnet model (alpha=0.002024, l1_ratio=0.500000):
#   RMSE: 0.1206026491268604
#   R2: 0.9009052226334202
# Elasticnet model (alpha=0.002024, l1_ratio=0.600000):
#   RMSE: 0.12237616106860102
#   R2: 0.8979693339194041
# Elasticnet model (alpha=0.002024, l1_ratio=0.700000):
#   RMSE: 0.1244497187286537
#   R2: 0.8944823986814454
# Elasticnet model (alpha=0.002024, l1_ratio=0.800000):
#   RMSE: 0.1266462917291398
#   R2: 0.8907246950469415
# Elasticnet model (alpha=0.002024, l1_ratio=0.900000):
#   RMSE: 0.12855436401473158
#   R2: 0.887407174045897
# Elasticnet model (alpha=0.002024, l1_ratio=1.000000):
#   RMSE: 0.13060563948379178
#   R2: 0.8837853359309106
# Elasticnet model (alpha=0.002121, l1_ratio=0.000000):
#   RMSE: 0.12004580195471104
#   R2: 0.9018181919051124
# Elasticnet model (alpha=0.002121, l1_ratio=0.100000):
#   RMSE: 0.11823805584510672
#   R2: 0.9047529285133081
# Elasticnet model (alpha=0.002121, l1_ratio=0.200000):
#   RMSE: 0.11781580768155728
#   R2: 0.9054320007165311
# Elasticnet model (alpha=0.002121, l1_ratio=0.300000):
#   RMSE: 0.11866556492480826
#   R2: 0.9040629205345254
# Elasticnet model (alpha=0.002121, l1_ratio=0.400000):
#   RMSE: 0.11964627725707279
#   R2: 0.902470622600587
# Elasticnet model (alpha=0.002121, l1_ratio=0.500000):
#   RMSE: 0.12105580074586174
#   R2: 0.9001591474530523
# Elasticnet model (alpha=0.002121, l1_ratio=0.600000):
#   RMSE: 0.12301717133223873
#   R2: 0.8968976546916239
# Elasticnet model (alpha=0.002121, l1_ratio=0.700000):
#   RMSE: 0.12523299919875355
#   R2: 0.893149973435967
# Elasticnet model (alpha=0.002121, l1_ratio=0.800000):
#   RMSE: 0.12745062428456955
#   R2: 0.8893322690840336
# Elasticnet model (alpha=0.002121, l1_ratio=0.900000):
#   RMSE: 0.12947695962664238
#   R2: 0.8857852859503327
# Elasticnet model (alpha=0.002121, l1_ratio=1.000000):
#   RMSE: 0.13165511817819564
#   R2: 0.8819101514110271
# Elasticnet model (alpha=0.002223, l1_ratio=0.000000):
#   RMSE: 0.11998944915759278
#   R2: 0.901910348745143
# Elasticnet model (alpha=0.002223, l1_ratio=0.100000):
#   RMSE: 0.11820954989452032
#   R2: 0.9047988491097164
# Elasticnet model (alpha=0.002223, l1_ratio=0.200000):
#   RMSE: 0.11790690721502968
#   R2: 0.9052856972358231
# Elasticnet model (alpha=0.002223, l1_ratio=0.300000):
#   RMSE: 0.11886203830889219
#   R2: 0.9037449734233799
# Elasticnet model (alpha=0.002223, l1_ratio=0.400000):
#   RMSE: 0.11991979349628076
#   R2: 0.9020242006944624
# Elasticnet model (alpha=0.002223, l1_ratio=0.500000):
#   RMSE: 0.12155599719400678
#   R2: 0.8993323681599457
# Elasticnet model (alpha=0.002223, l1_ratio=0.600000):
#   RMSE: 0.12368881616712375
#   R2: 0.8957687521771293
# Elasticnet model (alpha=0.002223, l1_ratio=0.700000):
#   RMSE: 0.12608622691276516
#   R2: 0.8916890490499091
# Elasticnet model (alpha=0.002223, l1_ratio=0.800000):
#   RMSE: 0.12824869054332233
#   R2: 0.8879419784875777
# Elasticnet model (alpha=0.002223, l1_ratio=0.900000):
#   RMSE: 0.130466719983943
#   R2: 0.8840324293486455
# Elasticnet model (alpha=0.002223, l1_ratio=1.000000):
#   RMSE: 0.1327285455504995
#   R2: 0.8799766506230233
# Elasticnet model (alpha=0.002330, l1_ratio=0.000000):
#   RMSE: 0.11993433763718551
#   R2: 0.9020004338049304
# Elasticnet model (alpha=0.002330, l1_ratio=0.100000):
#   RMSE: 0.11817445150350592
#   R2: 0.904855374342443
# Elasticnet model (alpha=0.002330, l1_ratio=0.200000):
#   RMSE: 0.11802489140120646
#   R2: 0.9050960496358293
# Elasticnet model (alpha=0.002330, l1_ratio=0.300000):
#   RMSE: 0.11905496803294799
#   R2: 0.9034322490715986
# Elasticnet model (alpha=0.002330, l1_ratio=0.400000):
#   RMSE: 0.120249605886005
#   R2: 0.9014845388547315
# Elasticnet model (alpha=0.002330, l1_ratio=0.500000):
#   RMSE: 0.12210608444977071
#   R2: 0.8984191877107055
# Elasticnet model (alpha=0.002330, l1_ratio=0.600000):
#   RMSE: 0.1244351522073216
#   R2: 0.894507098366649
# Elasticnet model (alpha=0.002330, l1_ratio=0.700000):
#   RMSE: 0.12690562672248334
#   R2: 0.8902767083740845
# Elasticnet model (alpha=0.002330, l1_ratio=0.800000):
#   RMSE: 0.12912290269135646
#   R2: 0.8864090760337661
# Elasticnet model (alpha=0.002330, l1_ratio=0.900000):
#   RMSE: 0.1314966275748914
#   R2: 0.882194300877752
# Elasticnet model (alpha=0.002330, l1_ratio=1.000000):
#   RMSE: 0.13387360909478518
#   R2: 0.8778968087649243
# Elasticnet model (alpha=0.002442, l1_ratio=0.000000):
#   RMSE: 0.11988048707662799
#   R2: 0.9020884177287352
# Elasticnet model (alpha=0.002442, l1_ratio=0.100000):
#   RMSE: 0.11813549597655665
#   R2: 0.9049180917586619
# Elasticnet model (alpha=0.002442, l1_ratio=0.200000):
#   RMSE: 0.11818114766368949
#   R2: 0.9048445916107084
# Elasticnet model (alpha=0.002442, l1_ratio=0.300000):
#   RMSE: 0.11926619706645561
#   R2: 0.9030892813119376
# Elasticnet model (alpha=0.002442, l1_ratio=0.400000):
#   RMSE: 0.12060572100543761
#   R2: 0.9009001744690109
# Elasticnet model (alpha=0.002442, l1_ratio=0.500000):
#   RMSE: 0.12270022899446249
#   R2: 0.8974282375806015
# Elasticnet model (alpha=0.002442, l1_ratio=0.600000):
#   RMSE: 0.1251967805571816
#   R2: 0.893211768701157
# Elasticnet model (alpha=0.002442, l1_ratio=0.700000):
#   RMSE: 0.12772078763271172
#   R2: 0.8888625961671743
# Elasticnet model (alpha=0.002442, l1_ratio=0.800000):
#   RMSE: 0.1300833223479893
#   R2: 0.8847130069471325
# Elasticnet model (alpha=0.002442, l1_ratio=0.900000):
#   RMSE: 0.13256374873162066
#   R2: 0.8802745094885024
# Elasticnet model (alpha=0.002442, l1_ratio=1.000000):
#   RMSE: 0.13502877939898564
#   R2: 0.8757805062545847
# Elasticnet model (alpha=0.002560, l1_ratio=0.000000):
#   RMSE: 0.11982792838107521
#   R2: 0.9021742528312877
# Elasticnet model (alpha=0.002560, l1_ratio=0.100000):
#   RMSE: 0.11810371827331419
#   R2: 0.9049692377458809
# Elasticnet model (alpha=0.002560, l1_ratio=0.200000):
#   RMSE: 0.11833379628629442
#   R2: 0.90459861798231
# Elasticnet model (alpha=0.002560, l1_ratio=0.300000):
#   RMSE: 0.11949142728229492
#   R2: 0.9027229104103189
# Elasticnet model (alpha=0.002560, l1_ratio=0.400000):
#   RMSE: 0.12103668346108336
#   R2: 0.9001906789498966
# Elasticnet model (alpha=0.002560, l1_ratio=0.500000):
#   RMSE: 0.12335497370206241
#   R2: 0.8963306438434746
# Elasticnet model (alpha=0.002560, l1_ratio=0.600000):
#   RMSE: 0.12602445605193316
#   R2: 0.8917951482168178
# Elasticnet model (alpha=0.002560, l1_ratio=0.700000):
#   RMSE: 0.12853216947610546
#   R2: 0.887446048340456
# Elasticnet model (alpha=0.002560, l1_ratio=0.800000):
#   RMSE: 0.1310870365311753
#   R2: 0.8829270498653665
# Elasticnet model (alpha=0.002560, l1_ratio=0.900000):
#   RMSE: 0.13368958075987622
#   R2: 0.8782322744733293
# Elasticnet model (alpha=0.002560, l1_ratio=1.000000):
#   RMSE: 0.13615800890330074
#   R2: 0.873694153133904
# Elasticnet model (alpha=0.002683, l1_ratio=0.000000):
#   RMSE: 0.11977670424366396
#   R2: 0.9022578722098659
# Elasticnet model (alpha=0.002683, l1_ratio=0.100000):
#   RMSE: 0.11807994448634544
#   R2: 0.9050074924891255
# Elasticnet model (alpha=0.002683, l1_ratio=0.200000):
#   RMSE: 0.11848736378327004
#   R2: 0.904350843326725
# Elasticnet model (alpha=0.002683, l1_ratio=0.300000):
#   RMSE: 0.11972953756099491
#   R2: 0.9023348364949955
# Elasticnet model (alpha=0.002683, l1_ratio=0.400000):
#   RMSE: 0.1215106215926548
#   R2: 0.8994075105119541
# Elasticnet model (alpha=0.002683, l1_ratio=0.500000):
#   RMSE: 0.12403958995835926
#   R2: 0.8951767272181004
# Elasticnet model (alpha=0.002683, l1_ratio=0.600000):
#   RMSE: 0.12686144649706876
#   R2: 0.8903530919998401
# Elasticnet model (alpha=0.002683, l1_ratio=0.700000):
#   RMSE: 0.12942283655580528
#   R2: 0.8858807524962151
# Elasticnet model (alpha=0.002683, l1_ratio=0.800000):
#   RMSE: 0.13214695783959854
#   R2: 0.8810261787633741
# Elasticnet model (alpha=0.002683, l1_ratio=0.900000):
#   RMSE: 0.13484878200906947
#   R2: 0.8761114621000031
# Elasticnet model (alpha=0.002683, l1_ratio=1.000000):
#   RMSE: 0.13729167580085536
#   R2: 0.8715821237120774
# Elasticnet model (alpha=0.002812, l1_ratio=0.000000):
#   RMSE: 0.11972686964511449
#   R2: 0.9023391889637838
# Elasticnet model (alpha=0.002812, l1_ratio=0.100000):
#   RMSE: 0.11808889477496853
#   R2: 0.9049930913546177
# Elasticnet model (alpha=0.002812, l1_ratio=0.200000):
#   RMSE: 0.1186349469405924
#   R2: 0.9041124213485817
# Elasticnet model (alpha=0.002812, l1_ratio=0.300000):
#   RMSE: 0.1199906930120557
#   R2: 0.9019083150682866
# Elasticnet model (alpha=0.002812, l1_ratio=0.400000):
#   RMSE: 0.12203126622868019
#   R2: 0.8985436330616208
# Elasticnet model (alpha=0.002812, l1_ratio=0.500000):
#   RMSE: 0.12478155856826743
#   R2: 0.8939189321315886
# Elasticnet model (alpha=0.002812, l1_ratio=0.600000):
#   RMSE: 0.12766753200983486
#   R2: 0.8889552585727218
# Elasticnet model (alpha=0.002812, l1_ratio=0.700000):
#   RMSE: 0.13039418922362084
#   R2: 0.8841613339158274
# Elasticnet model (alpha=0.002812, l1_ratio=0.800000):
#   RMSE: 0.13323632080034073
#   R2: 0.8790565551998265
# Elasticnet model (alpha=0.002812, l1_ratio=0.900000):
#   RMSE: 0.13598753834364985
#   R2: 0.8740102263468376
# Elasticnet model (alpha=0.002812, l1_ratio=1.000000):
#   RMSE: 0.13851680947932957
#   R2: 0.8692800025713684
# Elasticnet model (alpha=0.002947, l1_ratio=0.000000):
#   RMSE: 0.1196784922811987
#   R2: 0.9024180955299381
# Elasticnet model (alpha=0.002947, l1_ratio=0.100000):
#   RMSE: 0.11813493039532
#   R2: 0.9049190021779067
# Elasticnet model (alpha=0.002947, l1_ratio=0.200000):
#   RMSE: 0.11880750091759748
#   R2: 0.9038332824211269
# Elasticnet model (alpha=0.002947, l1_ratio=0.300000):
#   RMSE: 0.12027362987516536
#   R2: 0.901445171228177
# Elasticnet model (alpha=0.002947, l1_ratio=0.400000):
#   RMSE: 0.1226012357822541
#   R2: 0.8975936783836955
# Elasticnet model (alpha=0.002947, l1_ratio=0.500000):
#   RMSE: 0.1255470223099165
#   R2: 0.8926134463909429
# Elasticnet model (alpha=0.002947, l1_ratio=0.600000):
#   RMSE: 0.12849428556608541
#   R2: 0.8875123874586013
# Elasticnet model (alpha=0.002947, l1_ratio=0.700000):
#   RMSE: 0.1314030427057367
#   R2: 0.8823619235462399
# Elasticnet model (alpha=0.002947, l1_ratio=0.800000):
#   RMSE: 0.134385483751134
#   R2: 0.8769612842974134
# Elasticnet model (alpha=0.002947, l1_ratio=0.900000):
#   RMSE: 0.13709872265952294
#   R2: 0.8719428334234968
# Elasticnet model (alpha=0.002947, l1_ratio=1.000000):
#   RMSE: 0.1398347049304927
#   R2: 0.8667807415340294
# Elasticnet model (alpha=0.003089, l1_ratio=0.000000):
#   RMSE: 0.119631652912862
#   R2: 0.9024944631420572
# Elasticnet model (alpha=0.003089, l1_ratio=0.100000):
#   RMSE: 0.11810884270418412
#   R2: 0.9049609909414005
# Elasticnet model (alpha=0.003089, l1_ratio=0.200000):
#   RMSE: 0.11900283285091595
#   R2: 0.9035168062306009
# Elasticnet model (alpha=0.003089, l1_ratio=0.300000):
#   RMSE: 0.12064050508295525
#   R2: 0.9008430031660978
# Elasticnet model (alpha=0.003089, l1_ratio=0.400000):
#   RMSE: 0.12322019146369075
#   R2: 0.8965570660761581
# Elasticnet model (alpha=0.003089, l1_ratio=0.500000):
#   RMSE: 0.1263760214732153
#   R2: 0.8911905965869744
# Elasticnet model (alpha=0.003089, l1_ratio=0.600000):
#   RMSE: 0.12936043366103153
#   R2: 0.8859907741083577
# Elasticnet model (alpha=0.003089, l1_ratio=0.700000):
#   RMSE: 0.1324679030262434
#   R2: 0.8804475737814557
# Elasticnet model (alpha=0.003089, l1_ratio=0.800000):
#   RMSE: 0.13552875960407829
#   R2: 0.8748588912823294
# Elasticnet model (alpha=0.003089, l1_ratio=0.900000):
#   RMSE: 0.1382928246210679
#   R2: 0.8697024152381927
# Elasticnet model (alpha=0.003089, l1_ratio=1.000000):
#   RMSE: 0.1412110594179478
#   R2: 0.864145354415372
# Elasticnet model (alpha=0.003237, l1_ratio=0.000000):
#   RMSE: 0.11958644563446723
#   R2: 0.9025681414201131
# Elasticnet model (alpha=0.003237, l1_ratio=0.100000):
#   RMSE: 0.1180833299500284
#   R2: 0.9050020453609797
# Elasticnet model (alpha=0.003237, l1_ratio=0.200000):
#   RMSE: 0.11921075832730255
#   R2: 0.9031793547695752
# Elasticnet model (alpha=0.003237, l1_ratio=0.300000):
#   RMSE: 0.12104124005532516
#   R2: 0.9001831638871044
# Elasticnet model (alpha=0.003237, l1_ratio=0.400000):
#   RMSE: 0.12388689000425865
#   R2: 0.8954346554565896
# Elasticnet model (alpha=0.003237, l1_ratio=0.500000):
#   RMSE: 0.127192817061725
#   R2: 0.8897795338082617
# Elasticnet model (alpha=0.003237, l1_ratio=0.600000):
#   RMSE: 0.13030898905941427
#   R2: 0.8843126634965532
# Elasticnet model (alpha=0.003237, l1_ratio=0.700000):
#   RMSE: 0.13356509889037566
#   R2: 0.8784589311370051
# Elasticnet model (alpha=0.003237, l1_ratio=0.800000):
#   RMSE: 0.1366328920629615
#   R2: 0.8728115738683926
# Elasticnet model (alpha=0.003237, l1_ratio=0.900000):
#   RMSE: 0.13958499640202954
#   R2: 0.867256106827628
# Elasticnet model (alpha=0.003237, l1_ratio=1.000000):
#   RMSE: 0.14254508549286307
#   R2: 0.8615663821905304
# Elasticnet model (alpha=0.003393, l1_ratio=0.000000):
#   RMSE: 0.11954297805628022
#   R2: 0.9026389580952142
# Elasticnet model (alpha=0.003393, l1_ratio=0.100000):
#   RMSE: 0.11807361933399081
#   R2: 0.9050176690858813
# Elasticnet model (alpha=0.003393, l1_ratio=0.200000):
#   RMSE: 0.11943713325966983
#   R2: 0.9028112910534398
# Elasticnet model (alpha=0.003393, l1_ratio=0.300000):
#   RMSE: 0.1214824818568168
#   R2: 0.8994540960413557
# Elasticnet model (alpha=0.003393, l1_ratio=0.400000):
#   RMSE: 0.12459556302192082
#   R2: 0.8942349387832865
# Elasticnet model (alpha=0.003393, l1_ratio=0.500000):
#   RMSE: 0.12800859723328376
#   R2: 0.888361151540384
# Elasticnet model (alpha=0.003393, l1_ratio=0.600000):
#   RMSE: 0.13131151045732112
#   R2: 0.8825257542637149
# Elasticnet model (alpha=0.003393, l1_ratio=0.700000):
#   RMSE: 0.13471397726678913
#   R2: 0.8763590344476403
# Elasticnet model (alpha=0.003393, l1_ratio=0.800000):
#   RMSE: 0.13777557995674036
#   R2: 0.8706752740032483
# Elasticnet model (alpha=0.003393, l1_ratio=0.900000):
#   RMSE: 0.14093386586517676
#   R2: 0.8646781890413252
# Elasticnet model (alpha=0.003393, l1_ratio=1.000000):
#   RMSE: 0.1439060443446647
#   R2: 0.8589103544573
# Elasticnet model (alpha=0.003556, l1_ratio=0.000000):
#   RMSE: 0.11950137139807637
#   R2: 0.9027067188739933
# Elasticnet model (alpha=0.003556, l1_ratio=0.100000):
#   RMSE: 0.11808011923867444
#   R2: 0.9050072113207309
# Elasticnet model (alpha=0.003556, l1_ratio=0.200000):
#   RMSE: 0.11967571295083934
#   R2: 0.902422627826347
# Elasticnet model (alpha=0.003556, l1_ratio=0.300000):
#   RMSE: 0.12196468292300211
#   R2: 0.8986543171112304
# Elasticnet model (alpha=0.003556, l1_ratio=0.400000):
#   RMSE: 0.1253349432034528
#   R2: 0.892975943376707
# Elasticnet model (alpha=0.003556, l1_ratio=0.500000):
#   RMSE: 0.12885403287337419
#   R2: 0.8868816393483523
# Elasticnet model (alpha=0.003556, l1_ratio=0.600000):
#   RMSE: 0.1323638985632863
#   R2: 0.8806352283672891
# Elasticnet model (alpha=0.003556, l1_ratio=0.700000):
#   RMSE: 0.13584571128633394
#   R2: 0.8742728892500846
# Elasticnet model (alpha=0.003556, l1_ratio=0.800000):
#   RMSE: 0.13901126789693402
#   R2: 0.868345084029682
# Elasticnet model (alpha=0.003556, l1_ratio=0.900000):
#   RMSE: 0.1422834972391814
#   R2: 0.8620740023705067
# Elasticnet model (alpha=0.003556, l1_ratio=1.000000):
#   RMSE: 0.14508057767253668
#   R2: 0.8565978629077938
# Elasticnet model (alpha=0.003728, l1_ratio=0.000000):
#   RMSE: 0.11946176049143299
#   R2: 0.9027712074453307
# Elasticnet model (alpha=0.003728, l1_ratio=0.100000):
#   RMSE: 0.1181063806703073
#   R2: 0.904964953164986
# Elasticnet model (alpha=0.003728, l1_ratio=0.200000):
#   RMSE: 0.11990841052978386
#   R2: 0.9020427998310626
# Elasticnet model (alpha=0.003728, l1_ratio=0.300000):
#   RMSE: 0.12249080922335513
#   R2: 0.897778069428742
# Elasticnet model (alpha=0.003728, l1_ratio=0.400000):
#   RMSE: 0.1261085808440441
#   R2: 0.8916506405696224
# Elasticnet model (alpha=0.003728, l1_ratio=0.500000):
#   RMSE: 0.12973544891720953
#   R2: 0.8853287915933377
# Elasticnet model (alpha=0.003728, l1_ratio=0.600000):
#   RMSE: 0.13344247849657864
#   R2: 0.8786819919928349
# Elasticnet model (alpha=0.003728, l1_ratio=0.700000):
#   RMSE: 0.13694149932880068
#   R2: 0.8722363741564693
# Elasticnet model (alpha=0.003728, l1_ratio=0.800000):
#   RMSE: 0.1403318359648989
#   R2: 0.8658318333002935
# Elasticnet model (alpha=0.003728, l1_ratio=0.900000):
#   RMSE: 0.14365430462450582
#   R2: 0.8594035484957141
# Elasticnet model (alpha=0.003728, l1_ratio=1.000000):
#   RMSE: 0.14615175279736092
#   R2: 0.8544724802355557
# Elasticnet model (alpha=0.003907, l1_ratio=0.000000):
#   RMSE: 0.11942429368905816
#   R2: 0.9028321856309328
# Elasticnet model (alpha=0.003907, l1_ratio=0.100000):
#   RMSE: 0.11817550702116446
#   R2: 0.9048536746978968
# Elasticnet model (alpha=0.003907, l1_ratio=0.200000):
#   RMSE: 0.12018726586258047
#   R2: 0.901586657513295
# Elasticnet model (alpha=0.003907, l1_ratio=0.300000):
#   RMSE: 0.12306431622923306
#   R2: 0.8968186140047089
# Elasticnet model (alpha=0.003907, l1_ratio=0.400000):
#   RMSE: 0.126944984169228
#   R2: 0.8902086404978369
# Elasticnet model (alpha=0.003907, l1_ratio=0.500000):
#   RMSE: 0.13068942357130373
#   R2: 0.8836361836773381
# Elasticnet model (alpha=0.003907, l1_ratio=0.600000):
#   RMSE: 0.13457289567694597
#   R2: 0.8766178692078613
# Elasticnet model (alpha=0.003907, l1_ratio=0.700000):
#   RMSE: 0.13808705680538605
#   R2: 0.8700898699483263
# Elasticnet model (alpha=0.003907, l1_ratio=0.800000):
#   RMSE: 0.1416994264169705
#   R2: 0.8632040449517563
# Elasticnet model (alpha=0.003907, l1_ratio=0.900000):
#   RMSE: 0.14484810159230177
#   R2: 0.8570570678175569
# Elasticnet model (alpha=0.003907, l1_ratio=1.000000):
#   RMSE: 0.14722652446083542
#   R2: 0.8523242479811413
# Elasticnet model (alpha=0.004095, l1_ratio=0.000000):
#   RMSE: 0.1193891326802391
#   R2: 0.9028893936800696
# Elasticnet model (alpha=0.004095, l1_ratio=0.100000):
#   RMSE: 0.11827991173688306
#   R2: 0.9046854822631394
# Elasticnet model (alpha=0.004095, l1_ratio=0.200000):
#   RMSE: 0.12050267464578415
#   R2: 0.9010694452735701
# Elasticnet model (alpha=0.004095, l1_ratio=0.300000):
#   RMSE: 0.12369278984636703
#   R2: 0.8957620549152119
# Elasticnet model (alpha=0.004095, l1_ratio=0.400000):
#   RMSE: 0.12772916820188515
#   R2: 0.8888480108318473
# Elasticnet model (alpha=0.004095, l1_ratio=0.500000):
#   RMSE: 0.13169346524727238
#   R2: 0.881841349542399
# Elasticnet model (alpha=0.004095, l1_ratio=0.600000):
#   RMSE: 0.13570895235700248
#   R2: 0.8745259064406132
# Elasticnet model (alpha=0.004095, l1_ratio=0.700000):
#   RMSE: 0.13932603815066513
#   R2: 0.867748183210516
# Elasticnet model (alpha=0.004095, l1_ratio=0.800000):
#   RMSE: 0.14301752271537393
#   R2: 0.8606472403867638
# Elasticnet model (alpha=0.004095, l1_ratio=0.900000):
#   RMSE: 0.14594410727460408
#   R2: 0.8548857037663842
# Elasticnet model (alpha=0.004095, l1_ratio=1.000000):
#   RMSE: 0.1480748489782923
#   R2: 0.8506175190244626
# Elasticnet model (alpha=0.004292, l1_ratio=0.000000):
#   RMSE: 0.11935645221222334
#   R2: 0.9029425507075813
# Elasticnet model (alpha=0.004292, l1_ratio=0.100000):
#   RMSE: 0.11841282118294288
#   R2: 0.9044711547901945
# Elasticnet model (alpha=0.004292, l1_ratio=0.200000):
#   RMSE: 0.12085156717755643
#   R2: 0.9004957468183155
# Elasticnet model (alpha=0.004292, l1_ratio=0.300000):
#   RMSE: 0.12436122775519247
#   R2: 0.8946324036095811
# Elasticnet model (alpha=0.004292, l1_ratio=0.400000):
#   RMSE: 0.12857006142225147
#   R2: 0.8873796755880515
# Elasticnet model (alpha=0.004292, l1_ratio=0.500000):
#   RMSE: 0.13275108488547122
#   R2: 0.8799358835648009
# Elasticnet model (alpha=0.004292, l1_ratio=0.600000):
#   RMSE: 0.13680462793438217
#   R2: 0.872491642962407
# Elasticnet model (alpha=0.004292, l1_ratio=0.700000):
#   RMSE: 0.14063910210146408
#   R2: 0.8652436493463084
# Elasticnet model (alpha=0.004292, l1_ratio=0.800000):
#   RMSE: 0.14431570178943345
#   R2: 0.8581059311080512
# Elasticnet model (alpha=0.004292, l1_ratio=0.900000):
#   RMSE: 0.14699590575493449
#   R2: 0.8527865304035999
# Elasticnet model (alpha=0.004292, l1_ratio=1.000000):
#   RMSE: 0.1487754720930246
#   R2: 0.8492005542444707
# Elasticnet model (alpha=0.004498, l1_ratio=0.000000):
#   RMSE: 0.11932643971810725
#   R2: 0.9029913552730506
# Elasticnet model (alpha=0.004498, l1_ratio=0.100000):
#   RMSE: 0.11858523321292444
#   R2: 0.9041927674912469
# Elasticnet model (alpha=0.004498, l1_ratio=0.200000):
#   RMSE: 0.12121960022440333
#   R2: 0.8998887772002478
# Elasticnet model (alpha=0.004498, l1_ratio=0.300000):
#   RMSE: 0.12508235263156267
#   R2: 0.8934068850849963
# Elasticnet model (alpha=0.004498, l1_ratio=0.400000):
#   RMSE: 0.12943982145876473
#   R2: 0.8858507974807996
# Elasticnet model (alpha=0.004498, l1_ratio=0.500000):
#   RMSE: 0.13383256287725342
#   R2: 0.8779716720012511
# Elasticnet model (alpha=0.004498, l1_ratio=0.600000):
#   RMSE: 0.1379181887647129
#   R2: 0.8704074124571655
# Elasticnet model (alpha=0.004498, l1_ratio=0.700000):
#   RMSE: 0.1420054211747605
#   R2: 0.8626125952540679
# Elasticnet model (alpha=0.004498, l1_ratio=0.800000):
#   RMSE: 0.1454757475503897
#   R2: 0.8558156027014974
# Elasticnet model (alpha=0.004498, l1_ratio=0.900000):
#   RMSE: 0.1479288737099776
#   R2: 0.8509119025665042
# Elasticnet model (alpha=0.004498, l1_ratio=1.000000):
#   RMSE: 0.1494464081301517
#   R2: 0.8478373601547918
# Elasticnet model (alpha=0.004715, l1_ratio=0.000000):
#   RMSE: 0.11929929485250555
#   R2: 0.9030354860979397
# Elasticnet model (alpha=0.004715, l1_ratio=0.100000):
#   RMSE: 0.11877924540002453
#   R2: 0.9038790188812366
# Elasticnet model (alpha=0.004715, l1_ratio=0.200000):
#   RMSE: 0.12163761567934676
#   R2: 0.899197136690596
# Elasticnet model (alpha=0.004715, l1_ratio=0.300000):
#   RMSE: 0.1258174821298029
#   R2: 0.8921502728138018
# Elasticnet model (alpha=0.004715, l1_ratio=0.400000):
#   RMSE: 0.13034336346462783
#   R2: 0.8842516207715745
# Elasticnet model (alpha=0.004715, l1_ratio=0.500000):
#   RMSE: 0.1349585603214493
#   R2: 0.8759096685013069
# Elasticnet model (alpha=0.004715, l1_ratio=0.600000):
#   RMSE: 0.13911563002164948
#   R2: 0.8681473310775452
# Elasticnet model (alpha=0.004715, l1_ratio=0.700000):
#   RMSE: 0.14331725004320298
#   R2: 0.8600625344473027
# Elasticnet model (alpha=0.004715, l1_ratio=0.800000):
#   RMSE: 0.14650603753693534
#   R2: 0.8537660819989301
# Elasticnet model (alpha=0.004715, l1_ratio=0.900000):
#   RMSE: 0.14864980043686532
#   R2: 0.8494552092856377
# Elasticnet model (alpha=0.004715, l1_ratio=1.000000):
#   RMSE: 0.15016027309546026
#   R2: 0.846380208903534
# Elasticnet model (alpha=0.004942, l1_ratio=0.000000):
#   RMSE: 0.11927522893698492
#   R2: 0.9030746029164205
# Elasticnet model (alpha=0.004942, l1_ratio=0.100000):
#   RMSE: 0.11899903080174251
#   R2: 0.9035229712600932
# Elasticnet model (alpha=0.004942, l1_ratio=0.200000):
#   RMSE: 0.1220840927233772
#   R2: 0.8984557745240629
# Elasticnet model (alpha=0.004942, l1_ratio=0.300000):
#   RMSE: 0.12657219571081169
#   R2: 0.8908525234468313
# Elasticnet model (alpha=0.004942, l1_ratio=0.400000):
#   RMSE: 0.1313065362037577
#   R2: 0.8825346542545157
# Elasticnet model (alpha=0.004942, l1_ratio=0.500000):
#   RMSE: 0.13607846295427814
#   R2: 0.8738416903031625
# Elasticnet model (alpha=0.004942, l1_ratio=0.600000):
#   RMSE: 0.14040299673151704
#   R2: 0.8656957283280722
# Elasticnet model (alpha=0.004942, l1_ratio=0.700000):
#   RMSE: 0.14457965310053839
#   R2: 0.8575864120859761
# Elasticnet model (alpha=0.004942, l1_ratio=0.800000):
#   RMSE: 0.14757715105062852
#   R2: 0.8516200175093834
# Elasticnet model (alpha=0.004942, l1_ratio=0.900000):
#   RMSE: 0.14930437621807308
#   R2: 0.8481264494824882
# Elasticnet model (alpha=0.004942, l1_ratio=1.000000):
#   RMSE: 0.15080403281880242
#   R2: 0.8450602030269199
# Elasticnet model (alpha=0.005179, l1_ratio=0.000000):
#   RMSE: 0.11925446431794173
#   R2: 0.9031083474545885
# Elasticnet model (alpha=0.005179, l1_ratio=0.100000):
#   RMSE: 0.11923736878031382
#   R2: 0.9031361249667346
# Elasticnet model (alpha=0.005179, l1_ratio=0.200000):
#   RMSE: 0.122562894678926
#   R2: 0.89765771945777
# Elasticnet model (alpha=0.005179, l1_ratio=0.300000):
#   RMSE: 0.1273817545346962
#   R2: 0.8894518385212855
# Elasticnet model (alpha=0.005179, l1_ratio=0.400000):
#   RMSE: 0.13231745171749906
#   R2: 0.8807189845043908
# Elasticnet model (alpha=0.005179, l1_ratio=0.500000):
#   RMSE: 0.13716449383516757
#   R2: 0.8718199367179311
# Elasticnet model (alpha=0.005179, l1_ratio=0.600000):
#   RMSE: 0.1417217373281977
#   R2: 0.8631609638643848
# Elasticnet model (alpha=0.005179, l1_ratio=0.700000):
#   RMSE: 0.14572177448696064
#   R2: 0.8553275042776423
# Elasticnet model (alpha=0.005179, l1_ratio=0.800000):
#   RMSE: 0.1483265929192396
#   R2: 0.8501091531262213
# Elasticnet model (alpha=0.005179, l1_ratio=0.900000):
#   RMSE: 0.1500095214928021
#   R2: 0.8466885035598631
# Elasticnet model (alpha=0.005179, l1_ratio=1.000000):
#   RMSE: 0.15136949522809148
#   R2: 0.8438960844337922
# Elasticnet model (alpha=0.005429, l1_ratio=0.000000):
#   RMSE: 0.11923723364024441
#   R2: 0.903136344531851
# Elasticnet model (alpha=0.005429, l1_ratio=0.100000):
#   RMSE: 0.11948996493901479
#   R2: 0.9027252913615061
# Elasticnet model (alpha=0.005429, l1_ratio=0.200000):
#   RMSE: 0.1230810878305696
#   R2: 0.8967904883051638
# Elasticnet model (alpha=0.005429, l1_ratio=0.300000):
#   RMSE: 0.12815564909611782
#   R2: 0.8881045104950872
# Elasticnet model (alpha=0.005429, l1_ratio=0.400000):
#   RMSE: 0.13338572388630596
#   R2: 0.8787851659166218
# Elasticnet model (alpha=0.005429, l1_ratio=0.500000):
#   RMSE: 0.13827148329921488
#   R2: 0.8697426271311871
# Elasticnet model (alpha=0.005429, l1_ratio=0.600000):
#   RMSE: 0.14305016804012016
#   R2: 0.860583615521645
# Elasticnet model (alpha=0.005429, l1_ratio=0.700000):
#   RMSE: 0.1467331725450226
#   R2: 0.853312304257742
# Elasticnet model (alpha=0.005429, l1_ratio=0.800000):
#   RMSE: 0.14899905578049696
#   R2: 0.8487469629293988
# Elasticnet model (alpha=0.005429, l1_ratio=0.900000):
#   RMSE: 0.1507031039294917
#   R2: 0.8452675273049632
# Elasticnet model (alpha=0.005429, l1_ratio=1.000000):
#   RMSE: 0.15196913763425232
#   R2: 0.842656839550239
# Elasticnet model (alpha=0.005690, l1_ratio=0.000000):
#   RMSE: 0.11922377904062638
#   R2: 0.9031582032773579
# Elasticnet model (alpha=0.005690, l1_ratio=0.100000):
#   RMSE: 0.11975145642358416
#   R2: 0.9022990741377385
# Elasticnet model (alpha=0.005690, l1_ratio=0.200000):
#   RMSE: 0.12364125932668985
#   R2: 0.8958488880542286
# Elasticnet model (alpha=0.005690, l1_ratio=0.300000):
#   RMSE: 0.12899394454481303
#   R2: 0.8866358547046544
# Elasticnet model (alpha=0.005690, l1_ratio=0.400000):
#   RMSE: 0.1344695196976164
#   R2: 0.8768073553533094
# Elasticnet model (alpha=0.005690, l1_ratio=0.500000):
#   RMSE: 0.13946037347982176
#   R2: 0.8674930312457049
# Elasticnet model (alpha=0.005690, l1_ratio=0.600000):
#   RMSE: 0.1443574072487884
#   R2: 0.8580239079833466
# Elasticnet model (alpha=0.005690, l1_ratio=0.700000):
#   RMSE: 0.147765449563827
#   R2: 0.8512411302019645
# Elasticnet model (alpha=0.005690, l1_ratio=0.800000):
#   RMSE: 0.14968055577643535
#   R2: 0.8473601799373542
# Elasticnet model (alpha=0.005690, l1_ratio=0.900000):
#   RMSE: 0.15125219658315117
#   R2: 0.8441379255402952
# Elasticnet model (alpha=0.005690, l1_ratio=1.000000):
#   RMSE: 0.15239636875239423
#   R2: 0.8417709177645798
# Elasticnet model (alpha=0.005964, l1_ratio=0.000000):
#   RMSE: 0.11921435126540467
#   R2: 0.9031735184535833
# Elasticnet model (alpha=0.005964, l1_ratio=0.100000):
#   RMSE: 0.11999462658045094
#   R2: 0.9019018836248718
# Elasticnet model (alpha=0.005964, l1_ratio=0.200000):
#   RMSE: 0.12425597821814682
#   R2: 0.8948106777893277
# Elasticnet model (alpha=0.005964, l1_ratio=0.300000):
#   RMSE: 0.1298899130429452
#   R2: 0.8850555720148766
# Elasticnet model (alpha=0.005964, l1_ratio=0.400000):
#   RMSE: 0.13558951002334602
#   R2: 0.8747466777755142
# Elasticnet model (alpha=0.005964, l1_ratio=0.500000):
#   RMSE: 0.14073395869686436
#   R2: 0.8650618103108658
# Elasticnet model (alpha=0.005964, l1_ratio=0.600000):
#   RMSE: 0.14549137485189195
#   R2: 0.8557846238736333
# Elasticnet model (alpha=0.005964, l1_ratio=0.700000):
#   RMSE: 0.14849089951936875
#   R2: 0.8497768904396956
# Elasticnet model (alpha=0.005964, l1_ratio=0.800000):
#   RMSE: 0.15039586618200587
#   R2: 0.8458977890008735
# Elasticnet model (alpha=0.005964, l1_ratio=0.900000):
#   RMSE: 0.15186180829829027
#   R2: 0.8428790106267832
# Elasticnet model (alpha=0.005964, l1_ratio=1.000000):
#   RMSE: 0.152867833234762
#   R2: 0.8407903854065676
# Elasticnet model (alpha=0.006251, l1_ratio=0.000000):
#   RMSE: 0.11920920871770833
#   R2: 0.9031818718783955
# Elasticnet model (alpha=0.006251, l1_ratio=0.100000):
#   RMSE: 0.12023985094815681
#   R2: 0.9015005218297053
# Elasticnet model (alpha=0.006251, l1_ratio=0.200000):
#   RMSE: 0.12491194217538956
#   R2: 0.8936971291900886
# Elasticnet model (alpha=0.006251, l1_ratio=0.300000):
#   RMSE: 0.13080636559512354
#   R2: 0.8834278438131684
# Elasticnet model (alpha=0.006251, l1_ratio=0.400000):
#   RMSE: 0.1366859990151156
#   R2: 0.8727126825654575
# Elasticnet model (alpha=0.006251, l1_ratio=0.500000):
#   RMSE: 0.14203161410178078
#   R2: 0.8625619083138727
# Elasticnet model (alpha=0.006251, l1_ratio=0.600000):
#   RMSE: 0.146527628355297
#   R2: 0.8537229773915875
# Elasticnet model (alpha=0.006251, l1_ratio=0.700000):
#   RMSE: 0.1491453000325409
#   R2: 0.8484499040974601
# Elasticnet model (alpha=0.006251, l1_ratio=0.800000):
#   RMSE: 0.1510003995994455
#   R2: 0.844656436134743
# Elasticnet model (alpha=0.006251, l1_ratio=0.900000):
#   RMSE: 0.1523140085984643
#   R2: 0.841941896250099
# Elasticnet model (alpha=0.006251, l1_ratio=1.000000):
#   RMSE: 0.15338044025438172
#   R2: 0.8397208497462028
# Elasticnet model (alpha=0.006551, l1_ratio=0.000000):
#   RMSE: 0.11920861643993605
#   R2: 0.9031828339363339
# Elasticnet model (alpha=0.006551, l1_ratio=0.100000):
#   RMSE: 0.1205240846089438
#   R2: 0.9010342877519321
# Elasticnet model (alpha=0.006551, l1_ratio=0.200000):
#   RMSE: 0.12561427015971058
#   R2: 0.8924983747826214
# Elasticnet model (alpha=0.006551, l1_ratio=0.300000):
#   RMSE: 0.131756374706388
#   R2: 0.8817284347184975
# Elasticnet model (alpha=0.006551, l1_ratio=0.400000):
#   RMSE: 0.13775563032358762
#   R2: 0.8707127232239875
# Elasticnet model (alpha=0.006551, l1_ratio=0.500000):
#   RMSE: 0.1433515392659505
#   R2: 0.8599955652452363
# Elasticnet model (alpha=0.006551, l1_ratio=0.600000):
#   RMSE: 0.14757351689475862
#   R2: 0.8516273252713376
# Elasticnet model (alpha=0.006551, l1_ratio=0.700000):
#   RMSE: 0.14983281574216542
#   R2: 0.8470494815387435
# Elasticnet model (alpha=0.006551, l1_ratio=0.800000):
#   RMSE: 0.1515762491811031
#   R2: 0.843469351905141
# Elasticnet model (alpha=0.006551, l1_ratio=0.900000):
#   RMSE: 0.15277470375259972
#   R2: 0.8409843123066223
# Elasticnet model (alpha=0.006551, l1_ratio=1.000000):
#   RMSE: 0.15394167704189785
#   R2: 0.8385457438159962
# Elasticnet model (alpha=0.006866, l1_ratio=0.000000):
#   RMSE: 0.11921284503769308
#   R2: 0.9031759651692151
# Elasticnet model (alpha=0.006866, l1_ratio=0.100000):
#   RMSE: 0.12085310219278547
#   R2: 0.9004932190643511
# Elasticnet model (alpha=0.006866, l1_ratio=0.200000):
#   RMSE: 0.12635903094311407
#   R2: 0.8912198522186506
# Elasticnet model (alpha=0.006866, l1_ratio=0.300000):
#   RMSE: 0.13275413133025965
#   R2: 0.8799303729070305
# Elasticnet model (alpha=0.006866, l1_ratio=0.400000):
#   RMSE: 0.13885956990559123
#   R2: 0.868632267786214
# Elasticnet model (alpha=0.006866, l1_ratio=0.500000):
#   RMSE: 0.14462264577017234
#   R2: 0.8575017023699945
# Elasticnet model (alpha=0.006866, l1_ratio=0.600000):
#   RMSE: 0.14834320754331046
#   R2: 0.8500755715613526
# Elasticnet model (alpha=0.006866, l1_ratio=0.700000):
#   RMSE: 0.15054848067673826
#   R2: 0.8455848792879772
# Elasticnet model (alpha=0.006866, l1_ratio=0.800000):
#   RMSE: 0.15212797188516508
#   R2: 0.8423277655863465
# Elasticnet model (alpha=0.006866, l1_ratio=0.900000):
#   RMSE: 0.1532779618461723
#   R2: 0.8399349535142393
# Elasticnet model (alpha=0.006866, l1_ratio=1.000000):
#   RMSE: 0.15455926825005004
#   R2: 0.837247684090932
# Elasticnet model (alpha=0.007197, l1_ratio=0.000000):
#   RMSE: 0.11922216955193173
#   R2: 0.9031608179357118
# Elasticnet model (alpha=0.007197, l1_ratio=0.100000):
#   RMSE: 0.1212060607752318
#   R2: 0.8999111395098499
# Elasticnet model (alpha=0.007197, l1_ratio=0.200000):
#   RMSE: 0.12710577829503678
#   R2: 0.8899303311761533
# Elasticnet model (alpha=0.007197, l1_ratio=0.300000):
#   RMSE: 0.1338008445457995
#   R2: 0.8780295066001326
# Elasticnet model (alpha=0.007197, l1_ratio=0.400000):
#   RMSE: 0.1400420364830111
#   R2: 0.8663854028795652
# Elasticnet model (alpha=0.007197, l1_ratio=0.500000):
#   RMSE: 0.1457360482880913
#   R2: 0.8552991608460931
# Elasticnet model (alpha=0.007197, l1_ratio=0.600000):
#   RMSE: 0.14901970550126262
#   R2: 0.8487050358259705
# Elasticnet model (alpha=0.007197, l1_ratio=0.700000):
#   RMSE: 0.15112922235572693
#   R2: 0.8443912670036133
# Elasticnet model (alpha=0.007197, l1_ratio=0.800000):
#   RMSE: 0.1525669513883096
#   R2: 0.8414164967214559
# Elasticnet model (alpha=0.007197, l1_ratio=0.900000):
#   RMSE: 0.15382576091120523
#   R2: 0.8387887982881039
# Elasticnet model (alpha=0.007197, l1_ratio=1.000000):
#   RMSE: 0.1551850513327245
#   R2: 0.8359271055368169
# Elasticnet model (alpha=0.007543, l1_ratio=0.000000):
#   RMSE: 0.11923686828644707
#   R2: 0.9031369381291536
# Elasticnet model (alpha=0.007543, l1_ratio=0.100000):
#   RMSE: 0.12156434025711368
#   R2: 0.899318548928524
# Elasticnet model (alpha=0.007543, l1_ratio=0.200000):
#   RMSE: 0.12787113203530667
#   R2: 0.8886007950745071
# Elasticnet model (alpha=0.007543, l1_ratio=0.300000):
#   RMSE: 0.13488431390795713
#   R2: 0.8760461656266212
# Elasticnet model (alpha=0.007543, l1_ratio=0.400000):
#   RMSE: 0.14129350028384555
#   R2: 0.8639866806682825
# Elasticnet model (alpha=0.007543, l1_ratio=0.500000):
#   RMSE: 0.14675610406548098
#   R2: 0.8532664518484553
# Elasticnet model (alpha=0.007543, l1_ratio=0.600000):
#   RMSE: 0.14968650968088362
#   R2: 0.8473480364632222
# Elasticnet model (alpha=0.007543, l1_ratio=0.700000):
#   RMSE: 0.15171099260322662
#   R2: 0.8431909329586484
# Elasticnet model (alpha=0.007543, l1_ratio=0.800000):
#   RMSE: 0.1530505051207305
#   R2: 0.8404096578641067
# Elasticnet model (alpha=0.007543, l1_ratio=0.900000):
#   RMSE: 0.15442814487995327
#   R2: 0.8375237151568627
# Elasticnet model (alpha=0.007543, l1_ratio=1.000000):
#   RMSE: 0.15572788660566111
#   R2: 0.8347772482921597
# Elasticnet model (alpha=0.007906, l1_ratio=0.000000):
#   RMSE: 0.1192572215982671
#   R2: 0.9031038669424792
# Elasticnet model (alpha=0.007906, l1_ratio=0.100000):
#   RMSE: 0.12195594029785531
#   R2: 0.8986688458344407
# Elasticnet model (alpha=0.007906, l1_ratio=0.200000):
#   RMSE: 0.12863198697973904
#   R2: 0.8872711626757506
# Elasticnet model (alpha=0.007906, l1_ratio=0.300000):
#   RMSE: 0.13597531152878636
#   R2: 0.8740328811342368
# Elasticnet model (alpha=0.007906, l1_ratio=0.400000):
#   RMSE: 0.1425720783347052
#   R2: 0.8615139486669585
# Elasticnet model (alpha=0.007906, l1_ratio=0.500000):
#   RMSE: 0.14776644670498112
#   R2: 0.8512391225054151
# Elasticnet model (alpha=0.007906, l1_ratio=0.600000):
#   RMSE: 0.1503906749646945
#   R2: 0.8459084271158608
# Elasticnet model (alpha=0.007906, l1_ratio=0.700000):
#   RMSE: 0.1522338380138975
#   R2: 0.842108240446988
# Elasticnet model (alpha=0.007906, l1_ratio=0.800000):
#   RMSE: 0.15357306481879274
#   R2: 0.8393180201807828
# Elasticnet model (alpha=0.007906, l1_ratio=0.900000):
#   RMSE: 0.15508257736063996
#   R2: 0.8361437198292136
# Elasticnet model (alpha=0.007906, l1_ratio=1.000000):
#   RMSE: 0.15630502771532484
#   R2: 0.8335503191309728
# Elasticnet model (alpha=0.008286, l1_ratio=0.000000):
#   RMSE: 0.11928351065877696
#   R2: 0.903061142669093
# Elasticnet model (alpha=0.008286, l1_ratio=0.100000):
#   RMSE: 0.12238134113379073
#   R2: 0.8979606960166784
# Elasticnet model (alpha=0.008286, l1_ratio=0.200000):
#   RMSE: 0.12942049290481952
#   R2: 0.8858848855112597
# Elasticnet model (alpha=0.008286, l1_ratio=0.300000):
#   RMSE: 0.13706067806178648
#   R2: 0.8720138947335754
# Elasticnet model (alpha=0.008286, l1_ratio=0.400000):
#   RMSE: 0.14387430868756224
#   R2: 0.8589725767067073
# Elasticnet model (alpha=0.008286, l1_ratio=0.500000):
#   RMSE: 0.1485144936260133
#   R2: 0.8497291479629941
# Elasticnet model (alpha=0.008286, l1_ratio=0.600000):
#   RMSE: 0.1510319669554492
#   R2: 0.8445914787150758
# Elasticnet model (alpha=0.008286, l1_ratio=0.700000):
#   RMSE: 0.15268019278252415
#   R2: 0.8411809951071598
# Elasticnet model (alpha=0.008286, l1_ratio=0.800000):
#   RMSE: 0.1541461978463644
#   R2: 0.8381164553994178
# Elasticnet model (alpha=0.008286, l1_ratio=0.900000):
#   RMSE: 0.15561507200762326
#   R2: 0.8350165475874596
# Elasticnet model (alpha=0.008286, l1_ratio=1.000000):
#   RMSE: 0.15694045783051075
#   R2: 0.8321942254707104
# Elasticnet model (alpha=0.008685, l1_ratio=0.000000):
#   RMSE: 0.11931601619367836
#   R2: 0.9030083025282616
# Elasticnet model (alpha=0.008685, l1_ratio=0.100000):
#   RMSE: 0.12282004844012034
#   R2: 0.8972278126492855
# Elasticnet model (alpha=0.008685, l1_ratio=0.200000):
#   RMSE: 0.1302717359992079
#   R2: 0.8843788000126604
# Elasticnet model (alpha=0.008685, l1_ratio=0.300000):
#   RMSE: 0.13811785211530234
#   R2: 0.8700319200013048
# Elasticnet model (alpha=0.008685, l1_ratio=0.400000):
#   RMSE: 0.14508544575072985
#   R2: 0.8565882392277722
# Elasticnet model (alpha=0.008685, l1_ratio=0.500000):
#   RMSE: 0.14917427968033112
#   R2: 0.8483910045534393
# Elasticnet model (alpha=0.008685, l1_ratio=0.600000):
#   RMSE: 0.15159315834145087
#   R2: 0.8434344262558405
# Elasticnet model (alpha=0.008685, l1_ratio=0.700000):
#   RMSE: 0.15317104638823545
#   R2: 0.8401581748958781
# Elasticnet model (alpha=0.008685, l1_ratio=0.800000):
#   RMSE: 0.15477557960450852
#   R2: 0.8367918096583042
# Elasticnet model (alpha=0.008685, l1_ratio=0.900000):
#   RMSE: 0.15618005926641962
#   R2: 0.8338163712649077
# Elasticnet model (alpha=0.008685, l1_ratio=1.000000):
#   RMSE: 0.15759932289373688
#   R2: 0.8307823085909165
# Elasticnet model (alpha=0.009103, l1_ratio=0.000000):
#   RMSE: 0.11935501721003575
#   R2: 0.9029448845037393
# Elasticnet model (alpha=0.009103, l1_ratio=0.100000):
#   RMSE: 0.12329459374033877
#   R2: 0.8964321074424175
# Elasticnet model (alpha=0.009103, l1_ratio=0.200000):
#   RMSE: 0.13118734664380288
#   R2: 0.8827478087393212
# Elasticnet model (alpha=0.009103, l1_ratio=0.300000):
#   RMSE: 0.13918171455527556
#   R2: 0.8680220325512207
# Elasticnet model (alpha=0.009103, l1_ratio=0.400000):
#   RMSE: 0.14616948199882657
#   R2: 0.854437171138561
# Elasticnet model (alpha=0.009103, l1_ratio=0.500000):
#   RMSE: 0.1498420784296591
#   R2: 0.8470305701055063
# Elasticnet model (alpha=0.009103, l1_ratio=0.600000):
#   RMSE: 0.15216739878152563
#   R2: 0.8422460273979713
# Elasticnet model (alpha=0.009103, l1_ratio=0.700000):
#   RMSE: 0.15369982552594585
#   R2: 0.839052653757936
# Elasticnet model (alpha=0.009103, l1_ratio=0.800000):
#   RMSE: 0.1553670894395528
#   R2: 0.8355419519834996
# Elasticnet model (alpha=0.009103, l1_ratio=0.900000):
#   RMSE: 0.15679775536737628
#   R2: 0.8324992508385085
# Elasticnet model (alpha=0.009103, l1_ratio=1.000000):
#   RMSE: 0.15802253021745602
#   R2: 0.829872275234393
# Elasticnet model (alpha=0.009541, l1_ratio=0.000000):
#   RMSE: 0.11940078971875658
#   R2: 0.9028704291844295
# Elasticnet model (alpha=0.009541, l1_ratio=0.100000):
#   RMSE: 0.1238240122243166
#   R2: 0.895540771095156
# Elasticnet model (alpha=0.009541, l1_ratio=0.200000):
#   RMSE: 0.13215425793394495
#   R2: 0.8810130336388328
# Elasticnet model (alpha=0.009541, l1_ratio=0.300000):
#   RMSE: 0.1403146951891291
#   R2: 0.8658646071323215
# Elasticnet model (alpha=0.009541, l1_ratio=0.400000):
#   RMSE: 0.14715100934383876
#   R2: 0.8524757001975903
# Elasticnet model (alpha=0.009541, l1_ratio=0.500000):
#   RMSE: 0.15054321438714957
#   R2: 0.8455956821936701
# Elasticnet model (alpha=0.009541, l1_ratio=0.600000):
#   RMSE: 0.15260275397789963
#   R2: 0.8413420590241778
# Elasticnet model (alpha=0.009541, l1_ratio=0.700000):
#   RMSE: 0.15428010899254982
#   R2: 0.8378350676330172
# Elasticnet model (alpha=0.009541, l1_ratio=0.800000):
#   RMSE: 0.15591502179469097
#   R2: 0.8343799197349714
# Elasticnet model (alpha=0.009541, l1_ratio=0.900000):
#   RMSE: 0.15747665433847183
#   R2: 0.8310456296623734
# Elasticnet model (alpha=0.009541, l1_ratio=1.000000):
#   RMSE: 0.15842774447878122
#   R2: 0.8289986457756144
# Elasticnet model (alpha=0.010000, l1_ratio=0.000000):
#   RMSE: 0.11945360546082318
#   R2: 0.9027844815961967
# Elasticnet model (alpha=0.010000, l1_ratio=0.100000):
#   RMSE: 0.12435703424678819
#   R2: 0.8946395095614784
# Elasticnet model (alpha=0.010000, l1_ratio=0.200000):
#   RMSE: 0.13310410031213407
#   R2: 0.8792964787669288
# Elasticnet model (alpha=0.010000, l1_ratio=0.300000):
#   RMSE: 0.14151439927844803
#   R2: 0.8635610603552755
# Elasticnet model (alpha=0.010000, l1_ratio=0.400000):
#   RMSE: 0.14810372343756734
#   R2: 0.8505592544516252
# Elasticnet model (alpha=0.010000, l1_ratio=0.500000):
#   RMSE: 0.15117218512684252
#   R2: 0.8443027820298943
# Elasticnet model (alpha=0.010000, l1_ratio=0.600000):
#   RMSE: 0.153081106807279
#   R2: 0.840345832895199
# Elasticnet model (alpha=0.010000, l1_ratio=0.700000):
#   RMSE: 0.15491641759509953
#   R2: 0.836494652036321
# Elasticnet model (alpha=0.010000, l1_ratio=0.800000):
#   RMSE: 0.1565004562395649
#   R2: 0.8331338341142271
# Elasticnet model (alpha=0.010000, l1_ratio=0.900000):
#   RMSE: 0.15794241650972585
#   R2: 0.8300447330208359
# Elasticnet model (alpha=0.010000, l1_ratio=1.000000):
#   RMSE: 0.15887248234925985
#   R2: 0.8280372292872219
